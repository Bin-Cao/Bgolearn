# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.colors import LogNorm
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import  RBF


import Bgolearn.BGOsampling as BGOS
# Out:
#  Bgolearn : A Bayesian global optimization package
#  10 Jul 2022, version 1, Bin Cao, MGI, SHU, Shanghai, CHINA.

# %%
def True_function(X):
    X = np.array(X)
    Y = 0.013*X**4 - 0.25*X**3 + 1.61*X**2 - 4.1*X + 8
    return Y

# %%
def generate_function(data, obs):
    print('------------12 original data-----------')
    data = np.array(data)
    # for one feature dataset
    data_matrix = np.array(data[:,0]).reshape(-1, 1)

    Measured_response = np.zeros(len(data_matrix))
    for i in range(obs):
        Measured_response += np.array(data[:,i+1])
    # for one feature dataset
    Measured_response = Measured_response/obs
    
    Measured_std = []
    for j in range(len(data_matrix)):
        std = np.std(np.array(data[j,1:1+obs]))
        Measured_std.append(std)
    Measured_std = np.array(Measured_std)  
    print('evaluated mean of y :', Measured_response)
    print('evaluated std of y :', Measured_std)
    print('---------------------------------------\n')
    return data_matrix,Measured_response,Measured_std

# %% [markdown]
# ## design virtual samples

# %%
virtual_samples = np.linspace(0,11,100)

# %% [markdown]
# ## define a callable Kriging model and sampling function

# %%
def Sam_function(X,real_std,obs):
    print('--------------Draw samples-------------')
    print('real std of added datum:', real_std)
    X = np.array(X)
    Y = np.zeros(1)
    Y_list = []
    for i in range(obs):
        __sam = 0.013*X**4 - 0.25*X**3 + 1.61*X**2 - 4.1*X + 8 + np.random.normal(loc=0.0, scale=real_std, size=None)
        Y_list.append(__sam)
        Y += __sam
        print(i+1,'-th sampling, result = ', __sam)
    cal_std = np.std(np.array(Y_list))
    print('evaluated mean of added datum:', Y/obs)
    print('evaluated std of added datum:', cal_std)
    print('---------------------------------------\n')
    return Y/obs, np.array(cal_std)

# %% [markdown]
# ## instantiate Bgolearn

# %%
Bgolearn = BGOS.Bgolearn()
method_name = 'EI_plugin'

# %%
obs = 3

data = pd.read_csv('data.csv')
data_matrix, Measured_response,Measured_std = generate_function(data,obs)
for i in range(500):
    plt.figure()
    ax1 = plt.subplot()
    ax1.set_ylim([3, 9])
    
   
    class Kriging_model(object):
        def fit_pre(self,xtrain,ytrain,xtest):
            # instantiated model
            kernel = RBF() 
            mdoel = GaussianProcessRegressor(kernel=kernel,normalize_y=True,alpha = Measured_std**2).fit(xtrain,ytrain)
            # defined the attribute's outputs
            mean,std = mdoel.predict(xtest,return_std=True)
            return mean,std  
    

    y_mean_pre,y_mean_std = Kriging_model().fit_pre(data_matrix, Measured_response, virtual_samples.reshape(-1,1))
    ax1.scatter(data_matrix,Measured_response,c='r',s=50,zorder=10,edgecolors=(0,0,0),label="training data")
    ax1.plot(virtual_samples,True_function(virtual_samples),'b',lw=2,label="ture function")
    ax1.plot(virtual_samples,y_mean_pre,'k--',lw=2,zorder=9,label="predicted function")
    ax1.fill_between(virtual_samples,y_mean_pre-y_mean_std,y_mean_pre+y_mean_std,alpha=0.2,color='lightblue')
    ax1.plot(virtual_samples,y_mean_pre-y_mean_std,'g--',lw=1,label=' ± Sn(x)') 
    ax1.plot(virtual_samples,y_mean_pre+y_mean_std,'g--',lw=1)

    
    Bgolearn = BGOS.Bgolearn()
    # min_search = False:  searching the global maximum
    model = Bgolearn.fit(Kriging_model,data_matrix,Measured_response,virtual_samples,opt_num = 1,min_search = True)
    # recall the utility function 
    _return = model.EI_plugin()*10 + 3
    
    
    index = np.random.choice(np.flatnonzero(_return == _return.max()))
    recommend = virtual_samples[index]
    ax1.plot(virtual_samples,_return,'y--',lw=2,label='{name}(x)'.format(name = method_name))
    
    # give an intrinsic std to recommended datum
    sam_std = round(random.uniform(0.1,0.7),1)
    datum_y, datum_std = Sam_function(round(recommend,1),sam_std,obs)
    Measured_std = np.append(Measured_std,datum_std)
    data_matrix = np.append(data_matrix,np.round(recommend,1)).reshape(-1,1)
    Measured_response = np.append(Measured_response,np.round(datum_y,4))

    print("{num}-th iteration".format(num = i + 1),'\n', 'new added datum:',([np.round(recommend,1),np.round(datum_y,4)]))
    ax1.scatter(round(recommend,1),_return[index],c='red',s=1.5,linewidths=8,label="recommended datum") 
    
    
    plt.text(0.1,3.2,'Method : {name}'.format(name = method_name),fontsize=12,color='k')
    plt.text(0.1,3.7,'Iter={}'.format(i),fontsize=12,color='k')
    plt.xlabel('x',fontsize = 12)
    plt.ylabel('y',fontsize = 12)
    plt.legend(fontsize = 11)
    plt.savefig('{name}-obs_{obstime}-{num}.png'.format(name = method_name,obstime = obs,num = i),dpi=800)
    plt.show()
    plt.clf()
    if 7.6 <= round(recommend,1) <= 7.8:
        break
    elif i>=10:
        print('Searching is defeated')
        break
# Out:
# ------------12 original data-----------
# evaluated mean of y : [6.21494888 5.56581958 4.61988109 4.34056442 4.35646479 4.67190767
#  4.62173112 4.55605355 4.70138419 4.48867457 5.8769712  7.75473896]
# evaluated std of y : [0.30008321 0.2742029  0.07394358 0.91538122 0.33136727 0.29720623
#  0.07801782 0.48293232 0.24548787 0.12272781 0.21645983 0.25832216]
# ---------------------------------------
#
# current optimal is : 4.251646319418976
# The next datum recomended by Expected Improvement with plugin :
#  x =  [8.33333333]
# --------------Draw samples-------------
# real std of added datum: 0.4
# 1 -th sampling, result =  3.901019985339911
# 2 -th sampling, result =  3.308853971734663
# 3 -th sampling, result =  3.736527644329329
# evaluated mean of added datum: [3.64880053]
# evaluated std of added datum: 0.24958255996560907
# ---------------------------------------
#
# 1-th iteration
#  new added datum: [8.3, array([3.6488])]
# current optimal is : 3.7138635628541863
# The next datum recomended by Expected Improvement with plugin :
#  x =  [8.22222222]
# --------------Draw samples-------------
# real std of added datum: 0.3
# 1 -th sampling, result =  3.5311956451781525
# 2 -th sampling, result =  3.571743482493883
# 3 -th sampling, result =  3.5274058919876956
# evaluated mean of added datum: [3.54344834]
# evaluated std of added datum: 0.020067417682850728
# ---------------------------------------
#
# 2-th iteration
#  new added datum: [8.2, array([3.5434])]
# current optimal is : 3.5444109647266564
# The next datum recomended by Expected Improvement with plugin :
#  x =  [7.22222222]
# --------------Draw samples-------------
# real std of added datum: 0.2
# 1 -th sampling, result =  3.783477783689454
# 2 -th sampling, result =  3.402901676453727
# 3 -th sampling, result =  3.8816746811783363
# evaluated mean of added datum: [3.68935138]
# evaluated std of added datum: 0.20647959117016118
# ---------------------------------------
#
# 3-th iteration
#  new added datum: [7.2, array([3.6894])]
# current optimal is : 3.543878737419184
# The next datum recomended by Expected Improvement with plugin :
#  x =  [6.22222222]
# --------------Draw samples-------------
# real std of added datum: 0.2
# 1 -th sampling, result =  4.1432904067647405
# 2 -th sampling, result =  4.37535596541668
# 3 -th sampling, result =  4.151730258307507
# evaluated mean of added datum: [4.22345888]
# evaluated std of added datum: 0.10746271264778223
# ---------------------------------------
#
# 4-th iteration
#  new added datum: [6.2, array([4.2235])]
# current optimal is : 3.543831857666164
# The next datum recomended by Expected Improvement with plugin :
#  x =  [7.77777778]
# --------------Draw samples-------------
# real std of added datum: 0.4
# 1 -th sampling, result =  3.4521584257001474
# 2 -th sampling, result =  4.353584915605844
# 3 -th sampling, result =  3.634235504567526
# evaluated mean of added datum: [3.81332628]
# evaluated std of added datum: 0.3891850965677097
# ---------------------------------------
#
# 5-th iteration
#  new added datum: [7.8, array([3.8133])]

# %%
obs = 4

data = pd.read_csv('data.csv')
data_matrix, Measured_response,Measured_std = generate_function(data,obs)
for i in range(500):
    plt.figure()
    ax1 = plt.subplot()
    ax1.set_ylim([3, 9])
    
   
    class Kriging_model(object):
        def fit_pre(self,xtrain,ytrain,xtest):
            # instantiated model
            kernel = RBF() 
            mdoel = GaussianProcessRegressor(kernel=kernel,normalize_y=True,alpha = Measured_std**2).fit(xtrain,ytrain)
            # defined the attribute's outputs
            mean,std = mdoel.predict(xtest,return_std=True)
            return mean,std  
    

    y_mean_pre,y_mean_std = Kriging_model().fit_pre(data_matrix, Measured_response, virtual_samples.reshape(-1,1))
    ax1.scatter(data_matrix,Measured_response,c='r',s=50,zorder=10,edgecolors=(0,0,0),label="training data")
    ax1.plot(virtual_samples,True_function(virtual_samples),'b',lw=2,label="ture function")
    ax1.plot(virtual_samples,y_mean_pre,'k--',lw=2,zorder=9,label="predicted function")
    ax1.fill_between(virtual_samples,y_mean_pre-y_mean_std,y_mean_pre+y_mean_std,alpha=0.2,color='lightblue')
    ax1.plot(virtual_samples,y_mean_pre-y_mean_std,'g--',lw=1,label=' ± Sn(x)') 
    ax1.plot(virtual_samples,y_mean_pre+y_mean_std,'g--',lw=1)

    
    Bgolearn = BGOS.Bgolearn()
    # min_search = False:  searching the global maximum
    model = Bgolearn.fit(Kriging_model,data_matrix,Measured_response,virtual_samples,opt_num = 1,min_search = True)
    # recall the utility function 
    _return = model.EI_plugin()*10 + 3
    
    
    index = np.random.choice(np.flatnonzero(_return == _return.max()))
    recommend = virtual_samples[index]
    ax1.plot(virtual_samples,_return,'y--',lw=2,label='{name}(x)'.format(name = method_name))
    
    # give an intrinsic std to recommended datum
    sam_std = round(random.uniform(0.1,0.7),1)
    datum_y, datum_std = Sam_function(round(recommend,1),sam_std,obs)
    Measured_std = np.append(Measured_std,datum_std)
    data_matrix = np.append(data_matrix,np.round(recommend,1)).reshape(-1,1)
    Measured_response = np.append(Measured_response,np.round(datum_y,4))

    print("{num}-th iteration".format(num = i + 1),'\n', 'new added datum:',([np.round(recommend,1),np.round(datum_y,4)]))
    ax1.scatter(round(recommend,1),_return[index],c='red',s=1.5,linewidths=8,label="recommended datum") 
    
    
    plt.text(0.1,3.2,'Method : {name}'.format(name = method_name),fontsize=12,color='k')
    plt.text(0.1,3.7,'Iter={}'.format(i),fontsize=12,color='k')
    plt.xlabel('x',fontsize = 12)
    plt.ylabel('y',fontsize = 12)
    plt.legend(fontsize = 11)
    plt.savefig('{name}-obs_{obstime}-{num}.png'.format(name = method_name,obstime = obs,num = i),dpi=800)
    plt.show()
    plt.clf()
    if 7.6 <= round(recommend,1) <= 7.8:
        break
    elif i>=10:
        print('Searching is defeated')
        break
# Out:
# ------------12 original data-----------
# evaluated mean of y : [6.29185161 5.39856881 4.62623151 4.38385368 4.46148423 4.63694734
#  4.5905237  4.59016103 4.67177078 4.4811777  5.95522378 7.80150911]
# evaluated std of y : [0.29202661 0.37457828 0.06497479 0.79628133 0.33976528 0.26441507
#  0.08652626 0.42238334 0.21869861 0.10707566 0.23132562 0.23792876]
# ---------------------------------------
#
# current optimal is : 4.3718073781469755
# The next datum recomended by Expected Improvement with plugin :
#  x =  [8.44444444]
# --------------Draw samples-------------
# real std of added datum: 0.4
# 1 -th sampling, result =  3.4455542842551297
# 2 -th sampling, result =  3.6035469828436684
# 3 -th sampling, result =  4.12268734628794
# 4 -th sampling, result =  3.8809757784917016
# evaluated mean of added datum: [3.7631911]
# evaluated std of added datum: 0.259562214334867
# ---------------------------------------
#
# 1-th iteration
#  new added datum: [8.4, array([3.7632])]
# current optimal is : 3.813077837923616
# The next datum recomended by Expected Improvement with plugin :
#  x =  [8.22222222]
# --------------Draw samples-------------
# real std of added datum: 0.1
# 1 -th sampling, result =  3.5733855176077136
# 2 -th sampling, result =  3.6099765097859273
# 3 -th sampling, result =  3.4818764032828224
# 4 -th sampling, result =  3.5333800064272967
# evaluated mean of added datum: [3.54965461]
# evaluated std of added datum: 0.04759368549743337
# ---------------------------------------
#
# 2-th iteration
#  new added datum: [8.2, array([3.5497])]
# current optimal is : 3.556186991554816
# The next datum recomended by Expected Improvement with plugin :
#  x =  [7.22222222]
# --------------Draw samples-------------
# real std of added datum: 0.7
# 1 -th sampling, result =  3.9657631017488284
# 2 -th sampling, result =  2.663601068772121
# 3 -th sampling, result =  3.8406008318859928
# 4 -th sampling, result =  3.302104648284763
# evaluated mean of added datum: [3.44301741]
# evaluated std of added datum: 0.5144613384375459
# ---------------------------------------
#
# 3-th iteration
#  new added datum: [7.2, array([3.443])]
# current optimal is : 3.552992490300542
# The next datum recomended by Expected Improvement with plugin :
#  x =  [7.33333333]
# --------------Draw samples-------------
# real std of added datum: 0.2
# 1 -th sampling, result =  3.593425761058044
# 2 -th sampling, result =  3.7585006152246283
# 3 -th sampling, result =  3.1844552181507533
# 4 -th sampling, result =  3.427137017784924
# evaluated mean of added datum: [3.49087965]
# evaluated std of added datum: 0.2121884430858161
# ---------------------------------------
#
# 4-th iteration
#  new added datum: [7.3, array([3.4909])]
# current optimal is : 3.523784746134778
# The next datum recomended by Expected Improvement with plugin :
#  x =  [6.44444444]
# --------------Draw samples-------------
# real std of added datum: 0.1
# 1 -th sampling, result =  3.928853522035478
# 2 -th sampling, result =  3.9705322888418157
# 3 -th sampling, result =  3.891566333688605
# 4 -th sampling, result =  4.098242301526176
# evaluated mean of added datum: [3.97229861]
# evaluated std of added datum: 0.07789433456988228
# ---------------------------------------
#
# 5-th iteration
#  new added datum: [6.4, array([3.9723])]
# current optimal is : 3.525434920674781
# The next datum recomended by Expected Improvement with plugin :
#  x =  [7.44444444]
# --------------Draw samples-------------
# real std of added datum: 0.5
# 1 -th sampling, result =  3.9765075490453956
# 2 -th sampling, result =  4.09313465409408
# 3 -th sampling, result =  2.9477006195145483
# 4 -th sampling, result =  3.7532100908039867
# evaluated mean of added datum: [3.69263823]
# evaluated std of added datum: 0.44709623400462517
# ---------------------------------------
#
# 6-th iteration
#  new added datum: [7.4, array([3.6926])]
# current optimal is : 3.5354403980516222
# The next datum recomended by Expected Improvement with plugin :
#  x =  [7.55555556]
# --------------Draw samples-------------
# real std of added datum: 0.3
# 1 -th sampling, result =  3.3871960737563587
# 2 -th sampling, result =  3.46442345506189
# 3 -th sampling, result =  3.5226193857481762
# 4 -th sampling, result =  3.2943657461237477
# evaluated mean of added datum: [3.41715117]
# evaluated std of added datum: 0.0856326187493894
# ---------------------------------------
#
# 7-th iteration
#  new added datum: [7.6, array([3.4172])]

# %%
obs = 5

data = pd.read_csv('data.csv')
data_matrix, Measured_response,Measured_std = generate_function(data,obs)
for i in range(500):
    plt.figure()
    ax1 = plt.subplot()
    ax1.set_ylim([3, 9])
    
   
    class Kriging_model(object):
        def fit_pre(self,xtrain,ytrain,xtest):
            # instantiated model
            kernel = RBF() 
            mdoel = GaussianProcessRegressor(kernel=kernel,normalize_y=True,alpha = Measured_std**2).fit(xtrain,ytrain)
            # defined the attribute's outputs
            mean,std = mdoel.predict(xtest,return_std=True)
            return mean,std  
    

    y_mean_pre,y_mean_std = Kriging_model().fit_pre(data_matrix, Measured_response, virtual_samples.reshape(-1,1))
    ax1.scatter(data_matrix,Measured_response,c='r',s=50,zorder=10,edgecolors=(0,0,0),label="training data")
    ax1.plot(virtual_samples,True_function(virtual_samples),'b',lw=2,label="ture function")
    ax1.plot(virtual_samples,y_mean_pre,'k--',lw=2,zorder=9,label="predicted function")
    ax1.fill_between(virtual_samples,y_mean_pre-y_mean_std,y_mean_pre+y_mean_std,alpha=0.2,color='lightblue')
    ax1.plot(virtual_samples,y_mean_pre-y_mean_std,'g--',lw=1,label=' ± Sn(x)') 
    ax1.plot(virtual_samples,y_mean_pre+y_mean_std,'g--',lw=1)

    
    Bgolearn = BGOS.Bgolearn()
    # min_search = False:  searching the global maximum
    model = Bgolearn.fit(Kriging_model,data_matrix,Measured_response,virtual_samples,opt_num = 1,min_search = True)
    # recall the utility function 
    _return = model.EI_plugin()*10 + 3
    
    
    index = np.random.choice(np.flatnonzero(_return == _return.max()))
    recommend = virtual_samples[index]
    ax1.plot(virtual_samples,_return,'y--',lw=2,label='{name}(x)'.format(name = method_name))
    
    # give an intrinsic std to recommended datum
    sam_std = round(random.uniform(0.1,0.7),1)
    datum_y, datum_std = Sam_function(round(recommend,1),sam_std,obs)
    Measured_std = np.append(Measured_std,datum_std)
    data_matrix = np.append(data_matrix,np.round(recommend,1)).reshape(-1,1)
    Measured_response = np.append(Measured_response,np.round(datum_y,4))

    print("{num}-th iteration".format(num = i + 1),'\n', 'new added datum:',([np.round(recommend,1),np.round(datum_y,4)]))
    ax1.scatter(round(recommend,1),_return[index],c='red',s=1.5,linewidths=8,label="recommended datum") 
    
    
    plt.text(0.1,3.2,'Method : {name}'.format(name = method_name),fontsize=12,color='k')
    plt.text(0.1,3.7,'Iter={}'.format(i),fontsize=12,color='k')
    plt.xlabel('x',fontsize = 12)
    plt.ylabel('y',fontsize = 12)
    plt.legend(fontsize = 11)
    plt.savefig('{name}-obs_{obstime}-{num}.png'.format(name = method_name,obstime = obs,num = i),dpi=800)
    plt.show()
    plt.clf()
    if 7.6 <= round(recommend,1) <= 7.8:
        break
    elif i>=10:
        print('Searching is defeated')
        break
# Out:
# ------------12 original data-----------
# evaluated mean of y : [6.38302126 5.47159103 4.62333861 4.45561327 4.45288222 4.66633633
#  4.60958967 4.62022357 4.74050698 4.45448135 5.94232697 7.79008494]
# evaluated std of y : [0.31854553 0.36548063 0.05840252 0.72653212 0.30438189 0.24369472
#  0.0862756  0.38254565 0.23908561 0.10964916 0.20850551 0.21403299]
# ---------------------------------------
#
# current optimal is : 4.352956863309499
# The next datum recomended by Expected Improvement with plugin :
#  x =  [8.44444444]
# --------------Draw samples-------------
# real std of added datum: 0.2
# 1 -th sampling, result =  3.535150378959323
# 2 -th sampling, result =  3.781319124146945
# 3 -th sampling, result =  3.4259104349642366
# 4 -th sampling, result =  3.757145644570232
# 5 -th sampling, result =  3.5056541129535153
# evaluated mean of added datum: [3.60103594]
# evaluated std of added datum: 0.14211249694911976
# ---------------------------------------
#
# 1-th iteration
#  new added datum: [8.4, array([3.601])]
# current optimal is : 3.6271781251172643
# The next datum recomended by Expected Improvement with plugin :
#  x =  [7.77777778]
# --------------Draw samples-------------
# real std of added datum: 0.3
# 1 -th sampling, result =  3.266523905846088
# 2 -th sampling, result =  3.9562086448101055
# 3 -th sampling, result =  3.5142629194354518
# 4 -th sampling, result =  3.329040290879972
# 5 -th sampling, result =  3.552369545826883
# evaluated mean of added datum: [3.52368106]
# evaluated std of added datum: 0.24166368082464132
# ---------------------------------------
#
# 2-th iteration
#  new added datum: [7.8, array([3.5237])]
