# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.colors import LogNorm
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import  RBF


import Bgolearn.BGOsampling as BGOS
# Out:
#  Bgolearn : A Bayesian global optimization package
#  10 Jul 2022, version 1, Bin Cao, MGI, SHU, Shanghai, CHINA.

# %%
def True_function(X):
    X = np.array(X)
    Y = 0.013*X**4 - 0.25*X**3 + 1.61*X**2 - 4.1*X + 8
    return Y

# %%
def generate_function(data, obs):
    print('------------12 original data-----------')
    data = np.array(data)
    # for one feature dataset
    data_matrix = np.array(data[:,0]).reshape(-1, 1)

    Measured_response = np.zeros(len(data_matrix))
    for i in range(obs):
        Measured_response += np.array(data[:,i+1])
    # for one feature dataset
    Measured_response = Measured_response/obs
    
    Measured_std = []
    for j in range(len(data_matrix)):
        std = np.std(np.array(data[j,1:1+obs]))
        Measured_std.append(std)
    Measured_std = np.array(Measured_std)  
    print('evaluated mean of y :', Measured_response)
    print('evaluated std of y :', Measured_std)
    print('---------------------------------------\n')
    return data_matrix,Measured_response,Measured_std

# %% [markdown]
# ## design virtual samples

# %%
virtual_samples = np.linspace(0,11,100)

# %% [markdown]
# ## define a callable Kriging model and sampling function

# %%
def Sam_function(X,real_std,obs):
    print('--------------Draw samples-------------')
    print('real std of added datum:', real_std)
    X = np.array(X)
    Y = np.zeros(1)
    Y_list = []
    for i in range(obs):
        __sam = 0.013*X**4 - 0.25*X**3 + 1.61*X**2 - 4.1*X + 8 + np.random.normal(loc=0.0, scale=real_std, size=None)
        Y_list.append(__sam)
        Y += __sam
        print(i+1,'-th sampling, result = ', __sam)
    cal_std = np.std(np.array(Y_list))
    print('evaluated mean of added datum:', Y/obs)
    print('evaluated std of added datum:', cal_std)
    print('---------------------------------------\n')
    return Y/obs, np.array(cal_std)

# %% [markdown]
# ## instantiate Bgolearn

# %%
Bgolearn = BGOS.Bgolearn()
method_name = 'PES'

# %%
obs = 3

data = pd.read_csv('data.csv')
data_matrix, Measured_response,Measured_std = generate_function(data,obs)
for i in range(500):
    plt.figure()
    ax1 = plt.subplot()
    ax1.set_ylim([3, 9])
    
   
    class Kriging_model(object):
        def fit_pre(self,xtrain,ytrain,xtest):
            # instantiated model
            kernel = RBF() 
            if len(xtrain) != len(Measured_std):
                new_alpha = np.append(Measured_std,0.2)
                mdoel = GaussianProcessRegressor(kernel=kernel,normalize_y=True,alpha = new_alpha**2).fit(xtrain,ytrain)
            else:
                mdoel = GaussianProcessRegressor(kernel=kernel,normalize_y=True,alpha = Measured_std**2).fit(xtrain,ytrain)
            # defined the attribute's outputs
            mean,std = mdoel.predict(xtest,return_std=True)
            return mean,std  
    

    y_mean_pre,y_mean_std = Kriging_model().fit_pre(data_matrix, Measured_response, virtual_samples.reshape(-1,1))
    ax1.scatter(data_matrix,Measured_response,c='r',s=50,zorder=10,edgecolors=(0,0,0),label="training data")
    ax1.plot(virtual_samples,True_function(virtual_samples),'b',lw=2,label="ture function")
    ax1.plot(virtual_samples,y_mean_pre,'k--',lw=2,zorder=9,label="predicted function")
    ax1.fill_between(virtual_samples,y_mean_pre-y_mean_std,y_mean_pre+y_mean_std,alpha=0.2,color='lightblue')
    ax1.plot(virtual_samples,y_mean_pre-y_mean_std,'g--',lw=1,label=' ± Sn(x)') 
    ax1.plot(virtual_samples,y_mean_pre+y_mean_std,'g--',lw=1)

    
    Bgolearn = BGOS.Bgolearn()
    # min_search = False:  searching the global maximum
    model = Bgolearn.fit(Kriging_model,data_matrix,Measured_response,virtual_samples,opt_num = 1,min_search = True)
    # recall the utility function 
    _return = model.PES()*10 + 3
    
    
    index = np.random.choice(np.flatnonzero(_return == _return.max()))
    recommend = virtual_samples[index]
    ax1.plot(virtual_samples,_return,'y--',lw=2,label='{name}(x)'.format(name = method_name))
    
    # give an intrinsic std to recommended datum
    sam_std = round(random.uniform(0.1,0.7),1)
    datum_y, datum_std = Sam_function(round(recommend,1),sam_std,obs)
    Measured_std = np.append(Measured_std,datum_std)
    data_matrix = np.append(data_matrix,np.round(recommend,1)).reshape(-1,1)
    Measured_response = np.append(Measured_response,np.round(datum_y,4))

    print("{num}-th iteration".format(num = i + 1),'\n', 'new added datum:',([np.round(recommend,1),np.round(datum_y,4)]))
    ax1.scatter(round(recommend,1),_return[index],c='red',s=1.5,linewidths=8,label="recommended datum") 
    
    
    plt.text(0.1,3.2,'Method : {name}'.format(name = method_name),fontsize=12,color='k')
    plt.text(0.1,3.7,'Iter={}'.format(i),fontsize=12,color='k')
    plt.xlabel('x',fontsize = 12)
    plt.ylabel('y',fontsize = 12)
    plt.legend(fontsize = 11)
    plt.savefig('{name}-obs_{obstime}-{num}.png'.format(name = method_name,obstime = obs,num = i),dpi=800)
    plt.show()
    plt.clf()
    if 7.6 <= round(recommend,1) <= 7.8:
        break
    elif i>=10:
        print('Searching is defeated')
        break
# Out:
# ------------12 original data-----------
# evaluated mean of y : [6.21494888 5.56581958 4.61988109 4.34056442 4.35646479 4.67190767
#  4.62173112 4.55605355 4.70138419 4.48867457 5.8769712  7.75473896]
# evaluated std of y : [0.30008321 0.2742029  0.07394358 0.91538122 0.33136727 0.29720623
#  0.07801782 0.48293232 0.24548787 0.12272781 0.21645983 0.25832216]
# ---------------------------------------
#
# The next datum recomended by Predictive Entropy Search  :
#  x =  [7.88888889]
# --------------Draw samples-------------
# real std of added datum: 0.4
# 1 -th sampling, result =  3.3210214886725
# 2 -th sampling, result =  2.9885329823995717
# 3 -th sampling, result =  3.680158094437039
# evaluated mean of added datum: [3.32990419]
# evaluated std of added datum: 0.2824246219995929
# ---------------------------------------
#
# 1-th iteration
#  new added datum: [7.9, array([3.3299])]
# The next datum recomended by Predictive Entropy Search  :
#  x =  [6.88888889]
# --------------Draw samples-------------
# real std of added datum: 0.6
# 1 -th sampling, result =  3.440302897485635
# 2 -th sampling, result =  3.698717259686066
# 3 -th sampling, result =  4.333687740059131
# evaluated mean of added datum: [3.82423597]
# evaluated std of added datum: 0.3753667792198164
# ---------------------------------------
#
# 2-th iteration
#  new added datum: [6.9, array([3.8242])]
# The next datum recomended by Predictive Entropy Search  :
#  x =  [7.77777778]
# --------------Draw samples-------------
# real std of added datum: 0.4
# 1 -th sampling, result =  3.9909865269871565
# 2 -th sampling, result =  3.8113362090548675
# 3 -th sampling, result =  3.3176929850051855
# evaluated mean of added datum: [3.70667191]
# evaluated std of added datum: 0.2846600434549498
# ---------------------------------------
#
# 3-th iteration
#  new added datum: [7.8, array([3.7067])]

# %%
obs = 4

data = pd.read_csv('data.csv')
data_matrix, Measured_response,Measured_std = generate_function(data,obs)
for i in range(500):
    plt.figure()
    ax1 = plt.subplot()
    ax1.set_ylim([3, 9])
    
   
    class Kriging_model(object):
        def fit_pre(self,xtrain,ytrain,xtest):
            # instantiated model
            kernel = RBF() 
            if len(xtrain) != len(Measured_std):
                new_alpha = np.append(Measured_std,0.2)
                mdoel = GaussianProcessRegressor(kernel=kernel,normalize_y=True,alpha = new_alpha**2).fit(xtrain,ytrain)
            else:
                mdoel = GaussianProcessRegressor(kernel=kernel,normalize_y=True,alpha = Measured_std**2).fit(xtrain,ytrain)
            # defined the attribute's outputs
            mean,std = mdoel.predict(xtest,return_std=True)
            return mean,std  
    

    y_mean_pre,y_mean_std = Kriging_model().fit_pre(data_matrix, Measured_response, virtual_samples.reshape(-1,1))
    ax1.scatter(data_matrix,Measured_response,c='r',s=50,zorder=10,edgecolors=(0,0,0),label="training data")
    ax1.plot(virtual_samples,True_function(virtual_samples),'b',lw=2,label="ture function")
    ax1.plot(virtual_samples,y_mean_pre,'k--',lw=2,zorder=9,label="predicted function")
    ax1.fill_between(virtual_samples,y_mean_pre-y_mean_std,y_mean_pre+y_mean_std,alpha=0.2,color='lightblue')
    ax1.plot(virtual_samples,y_mean_pre-y_mean_std,'g--',lw=1,label=' ± Sn(x)') 
    ax1.plot(virtual_samples,y_mean_pre+y_mean_std,'g--',lw=1)

    
    Bgolearn = BGOS.Bgolearn()
    # min_search = False:  searching the global maximum
    model = Bgolearn.fit(Kriging_model,data_matrix,Measured_response,virtual_samples,opt_num = 1,min_search = True)
    # recall the utility function 
    _return = model.PES()*10 + 3
    
    
    index = np.random.choice(np.flatnonzero(_return == _return.max()))
    recommend = virtual_samples[index]
    ax1.plot(virtual_samples,_return,'y--',lw=2,label='{name}(x)'.format(name = method_name))
    
    # give an intrinsic std to recommended datum
    sam_std = round(random.uniform(0.1,0.7),1)
    datum_y, datum_std = Sam_function(round(recommend,1),sam_std,obs)
    Measured_std = np.append(Measured_std,datum_std)
    data_matrix = np.append(data_matrix,np.round(recommend,1)).reshape(-1,1)
    Measured_response = np.append(Measured_response,np.round(datum_y,4))

    print("{num}-th iteration".format(num = i + 1),'\n', 'new added datum:',([np.round(recommend,1),np.round(datum_y,4)]))
    ax1.scatter(round(recommend,1),_return[index],c='red',s=1.5,linewidths=8,label="recommended datum") 
    
    
    plt.text(0.1,3.2,'Method : {name}'.format(name = method_name),fontsize=12,color='k')
    plt.text(0.1,3.7,'Iter={}'.format(i),fontsize=12,color='k')
    plt.xlabel('x',fontsize = 12)
    plt.ylabel('y',fontsize = 12)
    plt.legend(fontsize = 11)
    plt.savefig('{name}-obs_{obstime}-{num}.png'.format(name = method_name,obstime = obs,num = i),dpi=800)
    plt.show()
    plt.clf()
    if 7.6 <= round(recommend,1) <= 7.8:
        break
    elif i>=10:
        print('Searching is defeated')
        break
# Out:
# ------------12 original data-----------
# evaluated mean of y : [6.29185161 5.39856881 4.62623151 4.38385368 4.46148423 4.63694734
#  4.5905237  4.59016103 4.67177078 4.4811777  5.95522378 7.80150911]
# evaluated std of y : [0.29202661 0.37457828 0.06497479 0.79628133 0.33976528 0.26441507
#  0.08652626 0.42238334 0.21869861 0.10707566 0.23132562 0.23792876]
# ---------------------------------------
#
# The next datum recomended by Predictive Entropy Search  :
#  x =  [8.]
# --------------Draw samples-------------
# real std of added datum: 0.3
# 1 -th sampling, result =  3.4206301178705147
# 2 -th sampling, result =  3.8578213927220544
# 3 -th sampling, result =  3.1961135562864675
# 4 -th sampling, result =  3.142111161739243
# evaluated mean of added datum: [3.40416906]
# evaluated std of added datum: 0.28197200219025065
# ---------------------------------------
#
# 1-th iteration
#  new added datum: [8.0, array([3.4042])]
# The next datum recomended by Predictive Entropy Search  :
#  x =  [6.88888889]
# --------------Draw samples-------------
# real std of added datum: 0.6
# 1 -th sampling, result =  3.683451121951808
# 2 -th sampling, result =  2.122981704844295
# 3 -th sampling, result =  5.319430125942771
# 4 -th sampling, result =  3.707945126127238
# evaluated mean of added datum: [3.70845202]
# evaluated std of added datum: 1.130220319220052
# ---------------------------------------
#
# 2-th iteration
#  new added datum: [6.9, array([3.7085])]
# The next datum recomended by Predictive Entropy Search  :
#  x =  [6.88888889]
# --------------Draw samples-------------
# real std of added datum: 0.4
# 1 -th sampling, result =  4.3126926810850765
# 2 -th sampling, result =  3.0029416890680145
# 3 -th sampling, result =  3.633509044023473
# 4 -th sampling, result =  2.8900545551826213
# evaluated mean of added datum: [3.45979949]
# evaluated std of added datum: 0.5680955345672036
# ---------------------------------------
#
# 3-th iteration
#  new added datum: [6.9, array([3.4598])]
# The next datum recomended by Predictive Entropy Search  :
#  x =  [6.]
# --------------Draw samples-------------
# real std of added datum: 0.2
# 1 -th sampling, result =  3.9085538286190196
# 2 -th sampling, result =  3.938628456102086
# 3 -th sampling, result =  4.209521862705868
# 4 -th sampling, result =  4.408358619784017
# evaluated mean of added datum: [4.11626569]
# evaluated std of added datum: 0.20537416926357313
# ---------------------------------------
#
# 4-th iteration
#  new added datum: [6.0, array([4.1163])]
# The next datum recomended by Predictive Entropy Search  :
#  x =  [7.33333333]
# --------------Draw samples-------------
# real std of added datum: 0.1
# 1 -th sampling, result =  3.4518318663498513
# 2 -th sampling, result =  3.5675819308442476
# 3 -th sampling, result =  3.59673651476693
# 4 -th sampling, result =  3.5114561944938893
# evaluated mean of added datum: [3.53190163]
# evaluated std of added datum: 0.05546582063555504
# ---------------------------------------
#
# 5-th iteration
#  new added datum: [7.3, array([3.5319])]
# The next datum recomended by Predictive Entropy Search  :
#  x =  [8.11111111]
# --------------Draw samples-------------
# real std of added datum: 0.2
# 1 -th sampling, result =  3.2211622817743106
# 2 -th sampling, result =  3.304355167675663
# 3 -th sampling, result =  3.543530017438636
# 4 -th sampling, result =  3.5993751414081476
# evaluated mean of added datum: [3.41710565]
# evaluated std of added datum: 0.15836016149622573
# ---------------------------------------
#
# 6-th iteration
#  new added datum: [8.1, array([3.4171])]
# The next datum recomended by Predictive Entropy Search  :
#  x =  [8.]
# --------------Draw samples-------------
# real std of added datum: 0.2
# 1 -th sampling, result =  3.5010719724410393
# 2 -th sampling, result =  3.633585975525308
# 3 -th sampling, result =  3.466272174065426
# 4 -th sampling, result =  3.6907548477259575
# evaluated mean of added datum: [3.57292124]
# evaluated std of added datum: 0.09233269973247102
# ---------------------------------------
#
# 7-th iteration
#  new added datum: [8.0, array([3.5729])]
# The next datum recomended by Predictive Entropy Search  :
#  x =  [6.66666667]
# --------------Draw samples-------------
# real std of added datum: 0.3
# 1 -th sampling, result =  3.737828127260837
# 2 -th sampling, result =  3.47693845879762
# 3 -th sampling, result =  3.9053281316056614
# 4 -th sampling, result =  3.5673749070718097
# evaluated mean of added datum: [3.67186741]
# evaluated std of added datum: 0.16414224314543305
# ---------------------------------------
#
# 8-th iteration
#  new added datum: [6.7, array([3.6719])]
# The next datum recomended by Predictive Entropy Search  :
#  x =  [8.11111111]
# --------------Draw samples-------------
# real std of added datum: 0.7
# 1 -th sampling, result =  3.2832462643104376
# 2 -th sampling, result =  4.1763559023733965
# 3 -th sampling, result =  3.6978138644767586
# 4 -th sampling, result =  2.70864420738954
# evaluated mean of added datum: [3.46651506]
# evaluated std of added datum: 0.5397519891495907
# ---------------------------------------
#
# 9-th iteration
#  new added datum: [8.1, array([3.4665])]
# The next datum recomended by Predictive Entropy Search  :
#  x =  [8.]
# --------------Draw samples-------------
# real std of added datum: 0.2
# 1 -th sampling, result =  3.542662943300336
# 2 -th sampling, result =  3.861113887849626
# 3 -th sampling, result =  3.428663062728114
# 4 -th sampling, result =  3.0174536203134457
# evaluated mean of added datum: [3.46247338]
# evaluated std of added datum: 0.3018817420060421
# ---------------------------------------
#
# 10-th iteration
#  new added datum: [8.0, array([3.4625])]
# The next datum recomended by Predictive Entropy Search  :
#  x =  [8.]
# --------------Draw samples-------------
# real std of added datum: 0.5
# 1 -th sampling, result =  3.419592425840176
# 2 -th sampling, result =  3.6245724727437385
# 3 -th sampling, result =  3.3432326947785773
# 4 -th sampling, result =  3.451887672821808
# evaluated mean of added datum: [3.45982132]
# evaluated std of added datum: 0.10297712918930385
# ---------------------------------------
#
# 11-th iteration
#  new added datum: [8.0, array([3.4598])]
# Searching is defeated

# %%
obs = 5

data = pd.read_csv('data.csv')
data_matrix, Measured_response,Measured_std = generate_function(data,obs)
for i in range(500):
    plt.figure()
    ax1 = plt.subplot()
    ax1.set_ylim([3, 9])
    
   
    class Kriging_model(object):
        def fit_pre(self,xtrain,ytrain,xtest):
            # instantiated model
            kernel = RBF() 
            if len(xtrain) != len(Measured_std):
                new_alpha = np.append(Measured_std,0.2)
                mdoel = GaussianProcessRegressor(kernel=kernel,normalize_y=True,alpha = new_alpha**2).fit(xtrain,ytrain)
            else:
                mdoel = GaussianProcessRegressor(kernel=kernel,normalize_y=True,alpha = Measured_std**2).fit(xtrain,ytrain)
            # defined the attribute's outputs
            mean,std = mdoel.predict(xtest,return_std=True)
            return mean,std  
    

    y_mean_pre,y_mean_std = Kriging_model().fit_pre(data_matrix, Measured_response, virtual_samples.reshape(-1,1))
    ax1.scatter(data_matrix,Measured_response,c='r',s=50,zorder=10,edgecolors=(0,0,0),label="training data")
    ax1.plot(virtual_samples,True_function(virtual_samples),'b',lw=2,label="ture function")
    ax1.plot(virtual_samples,y_mean_pre,'k--',lw=2,zorder=9,label="predicted function")
    ax1.fill_between(virtual_samples,y_mean_pre-y_mean_std,y_mean_pre+y_mean_std,alpha=0.2,color='lightblue')
    ax1.plot(virtual_samples,y_mean_pre-y_mean_std,'g--',lw=1,label=' ± Sn(x)') 
    ax1.plot(virtual_samples,y_mean_pre+y_mean_std,'g--',lw=1)

    
    Bgolearn = BGOS.Bgolearn()
    # min_search = False:  searching the global maximum
    model = Bgolearn.fit(Kriging_model,data_matrix,Measured_response,virtual_samples,opt_num = 1,min_search = True)
    # recall the utility function 
    _return = model.PES()*10 + 3
    
    
    index = np.random.choice(np.flatnonzero(_return == _return.max()))
    recommend = virtual_samples[index]
    ax1.plot(virtual_samples,_return,'y--',lw=2,label='{name}(x)'.format(name = method_name))
    
    # give an intrinsic std to recommended datum
    sam_std = round(random.uniform(0.1,0.7),1)
    datum_y, datum_std = Sam_function(round(recommend,1),sam_std,obs)
    Measured_std = np.append(Measured_std,datum_std)
    data_matrix = np.append(data_matrix,np.round(recommend,1)).reshape(-1,1)
    Measured_response = np.append(Measured_response,np.round(datum_y,4))

    print("{num}-th iteration".format(num = i + 1),'\n', 'new added datum:',([np.round(recommend,1),np.round(datum_y,4)]))
    ax1.scatter(round(recommend,1),_return[index],c='red',s=1.5,linewidths=8,label="recommended datum") 
    
    
    plt.text(0.1,3.2,'Method : {name}'.format(name = method_name),fontsize=12,color='k')
    plt.text(0.1,3.7,'Iter={}'.format(i),fontsize=12,color='k')
    plt.xlabel('x',fontsize = 12)
    plt.ylabel('y',fontsize = 12)
    plt.legend(fontsize = 11)
    plt.savefig('{name}-obs_{obstime}-{num}.png'.format(name = method_name,obstime = obs,num = i),dpi=800)
    plt.show()
    plt.clf()
    if 7.6 <= round(recommend,1) <= 7.8:
        break
    elif i>=10:
        print('Searching is defeated')
        break
# Out:
# ------------12 original data-----------
# evaluated mean of y : [6.38302126 5.47159103 4.62333861 4.45561327 4.45288222 4.66633633
#  4.60958967 4.62022357 4.74050698 4.45448135 5.94232697 7.79008494]
# evaluated std of y : [0.31854553 0.36548063 0.05840252 0.72653212 0.30438189 0.24369472
#  0.0862756  0.38254565 0.23908561 0.10964916 0.20850551 0.21403299]
# ---------------------------------------
#
# The next datum recomended by Predictive Entropy Search  :
#  x =  [8.]
# --------------Draw samples-------------
# real std of added datum: 0.1
# 1 -th sampling, result =  3.4538878182143886
# 2 -th sampling, result =  3.5091733795289315
# 3 -th sampling, result =  3.27565767228722
# 4 -th sampling, result =  3.386043384965856
# 5 -th sampling, result =  3.4604333650603922
# evaluated mean of added datum: [3.41703912]
# evaluated std of added datum: 0.08084436676858729
# ---------------------------------------
#
# 1-th iteration
#  new added datum: [8.0, array([3.417])]
# The next datum recomended by Predictive Entropy Search  :
#  x =  [6.88888889]
# --------------Draw samples-------------
# real std of added datum: 0.6
# 1 -th sampling, result =  2.8732438504379334
# 2 -th sampling, result =  3.7557100558143066
# 3 -th sampling, result =  3.725795989633402
# 4 -th sampling, result =  4.3670977922658505
# 5 -th sampling, result =  3.688273953481416
# evaluated mean of added datum: [3.68202433]
# evaluated std of added datum: 0.475570418548309
# ---------------------------------------
#
# 2-th iteration
#  new added datum: [6.9, array([3.682])]
# The next datum recomended by Predictive Entropy Search  :
#  x =  [6.11111111]
# --------------Draw samples-------------
# real std of added datum: 0.4
# 1 -th sampling, result =  4.264901297858007
# 2 -th sampling, result =  4.040105320562082
# 3 -th sampling, result =  4.115528117972926
# 4 -th sampling, result =  4.551078567786817
# 5 -th sampling, result =  4.188020413146347
# evaluated mean of added datum: [4.23192674]
# evaluated std of added datum: 0.17619141429045634
# ---------------------------------------
#
# 3-th iteration
#  new added datum: [6.1, array([4.2319])]
# The next datum recomended by Predictive Entropy Search  :
#  x =  [7.22222222]
# --------------Draw samples-------------
# real std of added datum: 0.1
# 1 -th sampling, result =  3.4830370629102076
# 2 -th sampling, result =  3.595323192477021
# 3 -th sampling, result =  3.50746625810258
# 4 -th sampling, result =  3.7094532123345347
# 5 -th sampling, result =  3.509169663225012
# evaluated mean of added datum: [3.56088988]
# evaluated std of added datum: 0.08348274318826433
# ---------------------------------------
#
# 4-th iteration
#  new added datum: [7.2, array([3.5609])]
# The next datum recomended by Predictive Entropy Search  :
#  x =  [7.66666667]
# --------------Draw samples-------------
# real std of added datum: 0.4
# 1 -th sampling, result =  3.2050937971557527
# 2 -th sampling, result =  3.733384108236635
# 3 -th sampling, result =  3.112646929421029
# 4 -th sampling, result =  3.8026064500127097
# 5 -th sampling, result =  3.5994161960539706
# evaluated mean of added datum: [3.4906295]
# evaluated std of added datum: 0.28017688115115386
# ---------------------------------------
#
# 5-th iteration
#  new added datum: [7.7, array([3.4906])]
