# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.colors import LogNorm
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import  RBF


import Bgolearn.BGOsampling as BGOS

# %%
def True_function(X):
    X = np.array(X)
    Y = 0.013*X**4 - 0.25*X**3 + 1.61*X**2 - 4.1*X + 8
    return Y

# %%
def generate_function(data, obs):
    print('------------12 original data-----------')
    data = np.array(data)
    # for one feature dataset
    data_matrix = np.array(data[:,0]).reshape(-1, 1)

    Measured_response = np.zeros(len(data_matrix))
    for i in range(obs):
        Measured_response += np.array(data[:,i+1])
    # for one feature dataset
    Measured_response = Measured_response/obs
    
    Measured_std = []
    for j in range(len(data_matrix)):
        std = np.std(np.array(data[j,1:1+obs]))
        Measured_std.append(std)
    Measured_std = np.array(Measured_std)  
    print('evaluated mean of y :', Measured_response)
    print('evaluated std of y :', Measured_std)
    print('---------------------------------------\n')
    return data_matrix,Measured_response,Measured_std

# %% [markdown]
# ## design virtual samples

# %%
virtual_samples = np.linspace(0,11,100)

# %% [markdown]
# ## define a callable Kriging model and sampling function

# %%
def Sam_function(X,real_std,obs):
    print('--------------Draw samples-------------')
    print('real std of added datum:', real_std)
    X = np.array(X)
    Y = np.zeros(1)
    Y_list = []
    for i in range(obs):
        __sam = 0.013*X**4 - 0.25*X**3 + 1.61*X**2 - 4.1*X + 8 + np.random.normal(loc=0.0, scale=real_std, size=None)
        Y_list.append(__sam)
        Y += __sam
        print(i+1,'-th sampling, result = ', __sam)
    cal_std = np.std(np.array(Y_list))
    print('evaluated mean of added datum:', Y/obs)
    print('evaluated std of added datum:', cal_std)
    print('---------------------------------------\n')
    return Y/obs, np.array(cal_std), np.array(Y_list)

# %% [markdown]
# ## instantiate Bgolearn

# %%
Bgolearn = BGOS.Bgolearn()
method_name = 'PES'

# %%
obs = 5
guessed_noise_std = 0.3

data = pd.read_csv('data.csv')
data_matrix, Measured_response,Measured_std = generate_function(data,obs)
Y1=data.iloc[:,1:]

for i in range(500):
    plt.figure()
    ax1 = plt.subplot()
    ax1.set_ylim([3, 9])
    
   
    class Kriging_model(object):
        def fit_pre(self,xtrain,ytrain,xtest):
            # instantiated model
            kernel = RBF() 
            mdoel = GaussianProcessRegressor(kernel=kernel,normalize_y=True,alpha = guessed_noise_std**2).fit(xtrain,ytrain)
            # defined the attribute's outputs
            mean,std = mdoel.predict(xtest,return_std=True)
            return mean,std  
    

    y_mean_pre,y_mean_std = Kriging_model().fit_pre(data_matrix, Measured_response, virtual_samples.reshape(-1,1))
    ax1.scatter(data_matrix,Measured_response,c='r',s=50,zorder=10,edgecolors=(0,0,0),label="training data")
    ax1.plot(virtual_samples,True_function(virtual_samples),'b',lw=2,label="ture function")
    ax1.plot(virtual_samples,y_mean_pre,'k--',lw=2,zorder=9,label="predicted function")
    ax1.fill_between(virtual_samples,y_mean_pre-y_mean_std,y_mean_pre+y_mean_std,alpha=0.2,color='lightblue')
    ax1.plot(virtual_samples,y_mean_pre-y_mean_std,'g--',lw=1,label=' ± Sn(x)') 
    ax1.plot(virtual_samples,y_mean_pre+y_mean_std,'g--',lw=1)

    
    Bgolearn = BGOS.Bgolearn()
    # min_search = False:  searching the global maximum
    model = Bgolearn.fit(Kriging_model,data_matrix,Measured_response,virtual_samples,opt_num = 1,min_search = True)
    # recall the utility function 
    _return = model.PES()*10 + 3
    
    
    index = np.random.choice(np.flatnonzero(_return == _return.max()))
    recommend = virtual_samples[index]
    ax1.plot(virtual_samples,_return,'y--',lw=2,label='{name}(x)'.format(name = method_name))
    
    # give an intrinsic std to recommended datum
    sam_std = round(random.uniform(0.1,0.7),1)
    datum_y, datum_std, Y_list = Sam_function(round(recommend,1),sam_std,obs)
    Measured_std = np.append(Measured_std,datum_std)
    data_matrix = np.append(data_matrix,np.round(recommend,1)).reshape(-1,1)
    Measured_response = np.append(Measured_response,np.round(datum_y,4))
    Y1 = np.append(Y1,Y_list)
 
    Measured_std1=(pd.DataFrame(Measured_std.reshape(len(Measured_std),1),columns=['Measured_std']))
    Measured_response1=(pd.DataFrame(Measured_response.reshape(len(Measured_std),1),columns=['Measured_response']))
    data_matrix1=(pd.DataFrame(data_matrix.reshape(len(data_matrix),1),columns=['x']))
    Y1=(pd.DataFrame(Y1.reshape(len(data_matrix),5)))
    data_iter=(np.hstack((data_matrix1,Measured_response1,Measured_std1,Y1)))
    
 
    
    print("{num}-th iteration".format(num = i + 1),'\n', 'new added datum:',([np.round(recommend,1),np.round(datum_y,4)]))
    ax1.scatter(round(recommend,1),_return[index],c='red',s=1.5,linewidths=8,label="recommended datum") 
    
    
    plt.text(0.1,3.2,'Method : {name}'.format(name = method_name),fontsize=12,color='k')
    plt.text(0.1,3.7,'Iter={}'.format(i),fontsize=12,color='k')
    plt.xlabel('x',fontsize = 12)
    plt.ylabel('y',fontsize = 12)
    plt.legend(fontsize = 11)
    plt.savefig('{name}-sd_{sdlevel}-obs_{obstime}-{num}.png'.format(name = method_name,sdlevel=guessed_noise_std,obstime = obs,num = i),dpi=800)
    plt.show()
    plt.clf()
    if 7.6 <= round(recommend,1) <= 7.8:
        break
    elif i>=10:
        print('Searching is defeated')
        break
data_iter=pd.DataFrame(data_iter.reshape(len(data_matrix),8),columns=['x','y_mean',"y_sd","y1","y2","y3","y4","y5"])
data_iter.to_csv('sd{:.2f}data.csv'.format(guessed_noise_std),float_format='%.4f') #保留两位小数
# Out:
# ------------12 original data-----------
# evaluated mean of y : [6.38302126 5.47159103 4.62333861 4.45561327 4.45288222 4.66633633
#  4.60958967 4.62022357 4.74050698 4.45448135 5.94232697 7.79008494]
# evaluated std of y : [0.31854553 0.36548063 0.05840252 0.72653212 0.30438189 0.24369472
#  0.0862756  0.38254565 0.23908561 0.10964916 0.20850551 0.21403299]
# ---------------------------------------
#
# The next datum recomended by Predictive Entropy Search  :
#  x =  [8.]
# --------------Draw samples-------------
# real std of added datum: 0.2
# 1 -th sampling, result =  3.4354654100205413
# 2 -th sampling, result =  3.489868963202027
# 3 -th sampling, result =  3.8777449129096166
# 4 -th sampling, result =  3.780803588905595
# 5 -th sampling, result =  3.5551223890635573
# evaluated mean of added datum: [3.62780105]
# evaluated std of added datum: 0.1715704859514044
# ---------------------------------------
#
# 1-th iteration
#  new added datum: [8.0, array([3.6278])]
# The next datum recomended by Predictive Entropy Search  :
#  x =  [6.88888889]
# --------------Draw samples-------------
# real std of added datum: 0.2
# 1 -th sampling, result =  3.824044115019811
# 2 -th sampling, result =  3.7103909729591136
# 3 -th sampling, result =  3.8299026756662773
# 4 -th sampling, result =  3.9489311913966323
# 5 -th sampling, result =  3.7759604464443974
# evaluated mean of added datum: [3.81784588]
# evaluated std of added datum: 0.0783174181065203
# ---------------------------------------
#
# 2-th iteration
#  new added datum: [6.9, array([3.8178])]
# The next datum recomended by Predictive Entropy Search  :
#  x =  [5.88888889]
# --------------Draw samples-------------
# real std of added datum: 0.2
# 1 -th sampling, result =  4.406277565171877
# 2 -th sampling, result =  3.8994423703849153
# 3 -th sampling, result =  4.376764947974535
# 4 -th sampling, result =  4.299584122775143
# 5 -th sampling, result =  4.230072482686798
# evaluated mean of added datum: [4.2424283]
# evaluated std of added datum: 0.18218217195922476
# ---------------------------------------
#
# 3-th iteration
#  new added datum: [5.9, array([4.2424])]
# The next datum recomended by Predictive Entropy Search  :
#  x =  [7.88888889]
# --------------Draw samples-------------
# real std of added datum: 0.6
# 1 -th sampling, result =  3.046922891510296
# 2 -th sampling, result =  4.0457884610450385
# 3 -th sampling, result =  3.37998957413182
# 4 -th sampling, result =  2.498122173640674
# 5 -th sampling, result =  3.364168719105844
# evaluated mean of added datum: [3.26699836]
# evaluated std of added datum: 0.5036520458465163
# ---------------------------------------
#
# 4-th iteration
#  new added datum: [7.9, array([3.267])]
# The next datum recomended by Predictive Entropy Search  :
#  x =  [8.11111111]
# --------------Draw samples-------------
# real std of added datum: 0.2
# 1 -th sampling, result =  3.422525119283334
# 2 -th sampling, result =  3.4845772283073533
# 3 -th sampling, result =  3.529359715024875
# 4 -th sampling, result =  3.716285141515678
# 5 -th sampling, result =  3.6028882324309537
# evaluated mean of added datum: [3.55112709]
# evaluated std of added datum: 0.10138793559693485
# ---------------------------------------
#
# 5-th iteration
#  new added datum: [8.1, array([3.5511])]
# The next datum recomended by Predictive Entropy Search  :
#  x =  [7.55555556]
# --------------Draw samples-------------
# real std of added datum: 0.6
# 1 -th sampling, result =  3.9625840507442405
# 2 -th sampling, result =  2.727236437266124
# 3 -th sampling, result =  3.1988773668277757
# 4 -th sampling, result =  4.145743290766793
# 5 -th sampling, result =  2.959974842735793
# evaluated mean of added datum: [3.3988832]
# evaluated std of added datum: 0.5584462190005657
# ---------------------------------------
#
# 6-th iteration
#  new added datum: [7.6, array([3.3989])]

# %%
obs = 5
guessed_noise_std = 0.5

data = pd.read_csv('data.csv')
data_matrix, Measured_response,Measured_std = generate_function(data,obs)
Y1=data.iloc[:,1:]

for i in range(500):
    plt.figure()
    ax1 = plt.subplot()
    ax1.set_ylim([3, 9])
    
   
    class Kriging_model(object):
        def fit_pre(self,xtrain,ytrain,xtest):
            # instantiated model
            kernel = RBF() 
            mdoel = GaussianProcessRegressor(kernel=kernel,normalize_y=True,alpha = guessed_noise_std**2).fit(xtrain,ytrain)
            # defined the attribute's outputs
            mean,std = mdoel.predict(xtest,return_std=True)
            return mean,std  
    

    y_mean_pre,y_mean_std = Kriging_model().fit_pre(data_matrix, Measured_response, virtual_samples.reshape(-1,1))
    ax1.scatter(data_matrix,Measured_response,c='r',s=50,zorder=10,edgecolors=(0,0,0),label="training data")
    ax1.plot(virtual_samples,True_function(virtual_samples),'b',lw=2,label="ture function")
    ax1.plot(virtual_samples,y_mean_pre,'k--',lw=2,zorder=9,label="predicted function")
    ax1.fill_between(virtual_samples,y_mean_pre-y_mean_std,y_mean_pre+y_mean_std,alpha=0.2,color='lightblue')
    ax1.plot(virtual_samples,y_mean_pre-y_mean_std,'g--',lw=1,label=' ± Sn(x)') 
    ax1.plot(virtual_samples,y_mean_pre+y_mean_std,'g--',lw=1)

    
    Bgolearn = BGOS.Bgolearn()
    # min_search = False:  searching the global maximum
    model = Bgolearn.fit(Kriging_model,data_matrix,Measured_response,virtual_samples,opt_num = 1,min_search = True)
    # recall the utility function 
    _return = model.PES()*10 + 3
    
    
    index = np.random.choice(np.flatnonzero(_return == _return.max()))
    recommend = virtual_samples[index]
    ax1.plot(virtual_samples,_return,'y--',lw=2,label='{name}(x)'.format(name = method_name))
    
    # give an intrinsic std to recommended datum
    sam_std = round(random.uniform(0.1,0.7),1)
    datum_y, datum_std, Y_list = Sam_function(round(recommend,1),sam_std,obs)
    Measured_std = np.append(Measured_std,datum_std)
    data_matrix = np.append(data_matrix,np.round(recommend,1)).reshape(-1,1)
    Measured_response = np.append(Measured_response,np.round(datum_y,4))
    Y1 = np.append(Y1,Y_list)
 
    Measured_std1=(pd.DataFrame(Measured_std.reshape(len(Measured_std),1),columns=['Measured_std']))
    Measured_response1=(pd.DataFrame(Measured_response.reshape(len(Measured_std),1),columns=['Measured_response']))
    data_matrix1=(pd.DataFrame(data_matrix.reshape(len(data_matrix),1),columns=['x']))
    Y1=(pd.DataFrame(Y1.reshape(len(data_matrix),5)))
    data_iter=(np.hstack((data_matrix1,Measured_response1,Measured_std1,Y1)))
    
 
    
    print("{num}-th iteration".format(num = i + 1),'\n', 'new added datum:',([np.round(recommend,1),np.round(datum_y,4)]))
    ax1.scatter(round(recommend,1),_return[index],c='red',s=1.5,linewidths=8,label="recommended datum") 
    
    
    plt.text(0.1,3.2,'Method : {name}'.format(name = method_name),fontsize=12,color='k')
    plt.text(0.1,3.7,'Iter={}'.format(i),fontsize=12,color='k')
    plt.xlabel('x',fontsize = 12)
    plt.ylabel('y',fontsize = 12)
    plt.legend(fontsize = 11)
    plt.savefig('{name}-sd_{sdlevel}-obs_{obstime}-{num}.png'.format(name = method_name,sdlevel=guessed_noise_std,obstime = obs,num = i),dpi=800)
    plt.show()
    plt.clf()
    if 7.6 <= round(recommend,1) <= 7.8:
        break
    elif i>=10:
        print('Searching is defeated')
        break
data_iter=pd.DataFrame(data_iter.reshape(len(data_matrix),8),columns=['x','y_mean',"y_sd","y1","y2","y3","y4","y5"])
data_iter.to_csv('sd{:.2f}data.csv'.format(guessed_noise_std),float_format='%.4f') #保留两位小数
# Out:
# ------------12 original data-----------
# evaluated mean of y : [6.38302126 5.47159103 4.62333861 4.45561327 4.45288222 4.66633633
#  4.60958967 4.62022357 4.74050698 4.45448135 5.94232697 7.79008494]
# evaluated std of y : [0.31854553 0.36548063 0.05840252 0.72653212 0.30438189 0.24369472
#  0.0862756  0.38254565 0.23908561 0.10964916 0.20850551 0.21403299]
# ---------------------------------------
#
# The next datum recomended by Predictive Entropy Search  :
#  x =  [8.]
# --------------Draw samples-------------
# real std of added datum: 0.4
# 1 -th sampling, result =  3.314466458968424
# 2 -th sampling, result =  2.9454688023105544
# 3 -th sampling, result =  3.4509154428071174
# 4 -th sampling, result =  2.5435949441765566
# 5 -th sampling, result =  2.604734020354634
# evaluated mean of added datum: [2.97183593]
# evaluated std of added datum: 0.36490059972534644
# ---------------------------------------
#
# 1-th iteration
#  new added datum: [8.0, array([2.9718])]
# The next datum recomended by Predictive Entropy Search  :
#  x =  [7.11111111]
# --------------Draw samples-------------
# real std of added datum: 0.4
# 1 -th sampling, result =  4.349257603743112
# 2 -th sampling, result =  3.1834006169819706
# 3 -th sampling, result =  3.5974131977554964
# 4 -th sampling, result =  3.5409757111549744
# 5 -th sampling, result =  3.658051575253892
# evaluated mean of added datum: [3.66581974]
# evaluated std of added datum: 0.37951056765124797
# ---------------------------------------
#
# 2-th iteration
#  new added datum: [7.1, array([3.6658])]
# The next datum recomended by Predictive Entropy Search  :
#  x =  [7.88888889]
# --------------Draw samples-------------
# real std of added datum: 0.4
# 1 -th sampling, result =  3.4914059415137
# 2 -th sampling, result =  3.232015498047585
# 3 -th sampling, result =  3.9013870370881603
# 4 -th sampling, result =  4.15712123822552
# 5 -th sampling, result =  3.3963185697923
# evaluated mean of added datum: [3.63564966]
# evaluated std of added datum: 0.3416299513322857
# ---------------------------------------
#
# 3-th iteration
#  new added datum: [7.9, array([3.6356])]
# The next datum recomended by Predictive Entropy Search  :
#  x =  [6.]
# --------------Draw samples-------------
# real std of added datum: 0.6
# 1 -th sampling, result =  3.967484238082116
# 2 -th sampling, result =  3.6522850558495126
# 3 -th sampling, result =  6.63786769603535
# 4 -th sampling, result =  5.193474695580281
# 5 -th sampling, result =  3.2751298689148314
# evaluated mean of added datum: [4.54524831]
# evaluated std of added datum: 1.2283036181840565
# ---------------------------------------
#
# 4-th iteration
#  new added datum: [6.0, array([4.5452])]
# The next datum recomended by Predictive Entropy Search  :
#  x =  [7.77777778]
# --------------Draw samples-------------
# real std of added datum: 0.4
# 1 -th sampling, result =  3.933990427131164
# 2 -th sampling, result =  3.3232721554091187
# 3 -th sampling, result =  3.9137968684231463
# 4 -th sampling, result =  3.1629536781864096
# 5 -th sampling, result =  3.649004542170384
# evaluated mean of added datum: [3.59660353]
# evaluated std of added datum: 0.30982241128943055
# ---------------------------------------
#
# 5-th iteration
#  new added datum: [7.8, array([3.5966])]

# %%
obs = 5
guessed_noise_std = 0.7

data = pd.read_csv('data.csv')
data_matrix, Measured_response,Measured_std = generate_function(data,obs)
Y1=data.iloc[:,1:]

for i in range(500):
    plt.figure()
    ax1 = plt.subplot()
    ax1.set_ylim([3, 9])
    
   
    class Kriging_model(object):
        def fit_pre(self,xtrain,ytrain,xtest):
            # instantiated model
            kernel = RBF() 
            mdoel = GaussianProcessRegressor(kernel=kernel,normalize_y=True,alpha = guessed_noise_std**2).fit(xtrain,ytrain)
            # defined the attribute's outputs
            mean,std = mdoel.predict(xtest,return_std=True)
            return mean,std  
    

    y_mean_pre,y_mean_std = Kriging_model().fit_pre(data_matrix, Measured_response, virtual_samples.reshape(-1,1))
    ax1.scatter(data_matrix,Measured_response,c='r',s=50,zorder=10,edgecolors=(0,0,0),label="training data")
    ax1.plot(virtual_samples,True_function(virtual_samples),'b',lw=2,label="ture function")
    ax1.plot(virtual_samples,y_mean_pre,'k--',lw=2,zorder=9,label="predicted function")
    ax1.fill_between(virtual_samples,y_mean_pre-y_mean_std,y_mean_pre+y_mean_std,alpha=0.2,color='lightblue')
    ax1.plot(virtual_samples,y_mean_pre-y_mean_std,'g--',lw=1,label=' ± Sn(x)') 
    ax1.plot(virtual_samples,y_mean_pre+y_mean_std,'g--',lw=1)

    
    Bgolearn = BGOS.Bgolearn()
    # min_search = False:  searching the global maximum
    model = Bgolearn.fit(Kriging_model,data_matrix,Measured_response,virtual_samples,opt_num = 1,min_search = True)
    # recall the utility function 
    _return = model.PES()*10 + 3
    
    
    index = np.random.choice(np.flatnonzero(_return == _return.max()))
    recommend = virtual_samples[index]
    ax1.plot(virtual_samples,_return,'y--',lw=2,label='{name}(x)'.format(name = method_name))
    
    # give an intrinsic std to recommended datum
    sam_std = round(random.uniform(0.1,0.7),1)
    datum_y, datum_std, Y_list = Sam_function(round(recommend,1),sam_std,obs)
    Measured_std = np.append(Measured_std,datum_std)
    data_matrix = np.append(data_matrix,np.round(recommend,1)).reshape(-1,1)
    Measured_response = np.append(Measured_response,np.round(datum_y,4))
    Y1 = np.append(Y1,Y_list)
 
    Measured_std1=(pd.DataFrame(Measured_std.reshape(len(Measured_std),1),columns=['Measured_std']))
    Measured_response1=(pd.DataFrame(Measured_response.reshape(len(Measured_std),1),columns=['Measured_response']))
    data_matrix1=(pd.DataFrame(data_matrix.reshape(len(data_matrix),1),columns=['x']))
    Y1=(pd.DataFrame(Y1.reshape(len(data_matrix),5)))
    data_iter=(np.hstack((data_matrix1,Measured_response1,Measured_std1,Y1)))
    
 
    
    print("{num}-th iteration".format(num = i + 1),'\n', 'new added datum:',([np.round(recommend,1),np.round(datum_y,4)]))
    ax1.scatter(round(recommend,1),_return[index],c='red',s=1.5,linewidths=8,label="recommended datum") 
    
    
    plt.text(0.1,3.2,'Method : {name}'.format(name = method_name),fontsize=12,color='k')
    plt.text(0.1,3.7,'Iter={}'.format(i),fontsize=12,color='k')
    plt.xlabel('x',fontsize = 12)
    plt.ylabel('y',fontsize = 12)
    plt.legend(fontsize = 11)
    plt.savefig('{name}-sd_{sdlevel}-obs_{obstime}-{num}.png'.format(name = method_name,sdlevel=guessed_noise_std,obstime = obs,num = i),dpi=800)
    plt.show()
    plt.clf()
    if 7.6 <= round(recommend,1) <= 7.8:
        break
    elif i>=10:
        print('Searching is defeated')
        break
data_iter=pd.DataFrame(data_iter.reshape(len(data_matrix),8),columns=['x','y_mean',"y_sd","y1","y2","y3","y4","y5"])
data_iter.to_csv('sd{:.2f}data.csv'.format(guessed_noise_std),float_format='%.4f') #保留两位小数
# Out:
# ------------12 original data-----------
# evaluated mean of y : [6.38302126 5.47159103 4.62333861 4.45561327 4.45288222 4.66633633
#  4.60958967 4.62022357 4.74050698 4.45448135 5.94232697 7.79008494]
# evaluated std of y : [0.31854553 0.36548063 0.05840252 0.72653212 0.30438189 0.24369472
#  0.0862756  0.38254565 0.23908561 0.10964916 0.20850551 0.21403299]
# ---------------------------------------
#
# The next datum recomended by Predictive Entropy Search  :
#  x =  [8.]
# --------------Draw samples-------------
# real std of added datum: 0.1
# 1 -th sampling, result =  3.576688678815855
# 2 -th sampling, result =  3.4325706503884303
# 3 -th sampling, result =  3.332420871461193
# 4 -th sampling, result =  3.4451157355553508
# 5 -th sampling, result =  3.3229065288992676
# evaluated mean of added datum: [3.42194049]
# evaluated std of added datum: 0.09210709181475323
# ---------------------------------------
#
# 1-th iteration
#  new added datum: [8.0, array([3.4219])]
# The next datum recomended by Predictive Entropy Search  :
#  x =  [7.]
# --------------Draw samples-------------
# real std of added datum: 0.4
# 1 -th sampling, result =  4.2946902837465695
# 2 -th sampling, result =  3.962735007346458
# 3 -th sampling, result =  2.4026005319148482
# 4 -th sampling, result =  3.4217205704365776
# 5 -th sampling, result =  3.6023740558935176
# evaluated mean of added datum: [3.53682409]
# evaluated std of added datum: 0.6418364238805218
# ---------------------------------------
#
# 2-th iteration
#  new added datum: [7.0, array([3.5368])]
# The next datum recomended by Predictive Entropy Search  :
#  x =  [6.]
# --------------Draw samples-------------
# real std of added datum: 0.5
# 1 -th sampling, result =  3.8766072749989364
# 2 -th sampling, result =  4.9690919035502
# 3 -th sampling, result =  4.077139408409283
# 4 -th sampling, result =  4.396970742127727
# 5 -th sampling, result =  4.405500404445653
# evaluated mean of added datum: [4.34506195]
# evaluated std of added datum: 0.3706731668806321
# ---------------------------------------
#
# 3-th iteration
#  new added datum: [6.0, array([4.3451])]
# The next datum recomended by Predictive Entropy Search  :
#  x =  [7.55555556]
# --------------Draw samples-------------
# real std of added datum: 0.6
# 1 -th sampling, result =  3.109943284862269
# 2 -th sampling, result =  3.6222270569211505
# 3 -th sampling, result =  3.861163505271976
# 4 -th sampling, result =  3.675026363218302
# 5 -th sampling, result =  3.659494413450858
# evaluated mean of added datum: [3.58557092]
# evaluated std of added datum: 0.251787033797591
# ---------------------------------------
#
# 4-th iteration
#  new added datum: [7.6, array([3.5856])]
