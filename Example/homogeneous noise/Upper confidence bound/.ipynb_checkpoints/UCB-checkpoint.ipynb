# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.colors import LogNorm
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import  RBF


import Bgolearn.BGOsampling as BGOS
# Out:
#  Bgolearn : A Bayesian global optimization package
#  10 Jul 2022, version 1, Bin Cao, MGI, SHU, Shanghai, CHINA.

# %%
def True_function(X):
    X = np.array(X)
    Y = 0.013*X**4 - 0.25*X**3 + 1.61*X**2 - 4.1*X + 8
    return Y

# %%
def generate_function(data, obs):
    print('------------12 original data-----------')
    data = np.array(data)
    # for one feature dataset
    data_matrix = np.array(data[:,0]).reshape(-1, 1)

    Measured_response = np.zeros(len(data_matrix))
    for i in range(obs):
        Measured_response += np.array(data[:,i+1])
    # for one feature dataset
    Measured_response = Measured_response/obs
    
    Measured_std = []
    for j in range(len(data_matrix)):
        std = np.std(np.array(data[j,1:1+obs]))
        Measured_std.append(std)
    Measured_std = np.array(Measured_std)  
    print('evaluated mean of y :', Measured_response)
    print('evaluated std of y :', Measured_std)
    print('---------------------------------------\n')
    return data_matrix,Measured_response,Measured_std

# %% [markdown]
# ## design virtual samples

# %%
virtual_samples = np.linspace(0,11,100)

# %% [markdown]
# ## define a callable Kriging model and sampling function

# %%
def Sam_function(X,real_std,obs):
    print('--------------Draw samples-------------')
    print('real std of added datum:', real_std)
    X = np.array(X)
    Y = np.zeros(1)
    Y_list = []
    for i in range(obs):
        __sam = 0.013*X**4 - 0.25*X**3 + 1.61*X**2 - 4.1*X + 8 + np.random.normal(loc=0.0, scale=real_std, size=None)
        Y_list.append(__sam)
        Y += __sam
        print(i+1,'-th sampling, result = ', __sam)
    cal_std = np.std(np.array(Y_list))
    print('evaluated mean of added datum:', Y/obs)
    print('evaluated std of added datum:', cal_std)
    print('---------------------------------------\n')
    return Y/obs, np.array(cal_std),np.array(Y_list)

# %% [markdown]
# ## instantiate Bgolearn

# %%
Bgolearn = BGOS.Bgolearn()
method_name = 'UCB'

# %%
obs = 5
guessed_noise_std = 0.3

data = pd.read_csv('data.csv')
data_matrix, Measured_response,Measured_std = generate_function(data,obs)
Y1=data.iloc[:,1:]

for i in range(500):
    plt.figure()
    ax1 = plt.subplot()
    ax1.set_ylim([3, 9])
    
   
    class Kriging_model(object):
        def fit_pre(self,xtrain,ytrain,xtest):
            # instantiated model
            kernel = RBF() 
            mdoel = GaussianProcessRegressor(kernel=kernel,normalize_y=True,alpha = guessed_noise_std**2).fit(xtrain,ytrain)
            # defined the attribute's outputs
            mean,std = mdoel.predict(xtest,return_std=True)
            return mean,std  
    

    y_mean_pre,y_mean_std = Kriging_model().fit_pre(data_matrix, Measured_response, virtual_samples.reshape(-1,1))
    ax1.scatter(data_matrix,Measured_response,c='r',s=50,zorder=10,edgecolors=(0,0,0),label="training data")
    ax1.plot(virtual_samples,True_function(virtual_samples),'b',lw=2,label="ture function")
    ax1.plot(virtual_samples,y_mean_pre,'k--',lw=2,zorder=9,label="predicted function")
    ax1.fill_between(virtual_samples,y_mean_pre-y_mean_std,y_mean_pre+y_mean_std,alpha=0.2,color='lightblue')
    ax1.plot(virtual_samples,y_mean_pre-y_mean_std,'g--',lw=1,label=' ± Sn(x)') 
    ax1.plot(virtual_samples,y_mean_pre+y_mean_std,'g--',lw=1)

    
    Bgolearn = BGOS.Bgolearn()
    # min_search = False:  searching the global maximum
    model = Bgolearn.fit(Kriging_model,data_matrix,Measured_response,virtual_samples,opt_num = 1,min_search = True)
    # recall the utility function 
    _return = model.UCB()
    
    
    index = np.random.choice(np.flatnonzero(_return == _return.min()))
    recommend = virtual_samples[index]
    ax1.plot(virtual_samples,_return,'y--',lw=2,label='{name}(x)'.format(name = method_name))
    
    # give an intrinsic std to recommended datum
    sam_std = round(random.uniform(0.1,0.7),1)
    datum_y, datum_std, Y_list = Sam_function(round(recommend,1),sam_std,obs)
    Measured_std = np.append(Measured_std,datum_std)
    data_matrix = np.append(data_matrix,np.round(recommend,1)).reshape(-1,1)
    Measured_response = np.append(Measured_response,np.round(datum_y,4))
    Y1 = np.append(Y1,Y_list)
 
    Measured_std1=(pd.DataFrame(Measured_std.reshape(len(Measured_std),1),columns=['Measured_std']))
    Measured_response1=(pd.DataFrame(Measured_response.reshape(len(Measured_std),1),columns=['Measured_response']))
    data_matrix1=(pd.DataFrame(data_matrix.reshape(len(data_matrix),1),columns=['x']))
    Y1=(pd.DataFrame(Y1.reshape(len(data_matrix),5)))
    data_iter=(np.hstack((data_matrix1,Measured_response1,Measured_std1,Y1)))
    
 
    
    print("{num}-th iteration".format(num = i + 1),'\n', 'new added datum:',([np.round(recommend,1),np.round(datum_y,4)]))
    ax1.scatter(round(recommend,1),_return[index],c='red',s=1.5,linewidths=8,label="recommended datum") 
    
    
    plt.text(0.1,3.2,'Method : {name}'.format(name = method_name),fontsize=12,color='k')
    plt.text(0.1,3.7,'Iter={}'.format(i),fontsize=12,color='k')
    plt.xlabel('x',fontsize = 12)
    plt.ylabel('y',fontsize = 12)
    plt.legend(fontsize = 11)
    plt.savefig('{name}-sd_{sdlevel}-obs_{obstime}-{num}.png'.format(name = method_name,sdlevel=guessed_noise_std,obstime = obs,num = i),dpi=800)
    plt.show()
    plt.clf()
    if 7.6 <= round(recommend,1) <= 7.8:
        break
    elif i>=10:
        print('Searching is defeated')
        break
data_iter=pd.DataFrame(data_iter.reshape(len(data_matrix),8),columns=['x','y_mean',"y_sd","y1","y2","y3","y4","y5"])
data_iter.to_csv('sd{:.2f}data.csv'.format(guessed_noise_std),float_format='%.4f') #保留两位小数
# Out:
# ------------12 original data-----------
# evaluated mean of y : [6.38302126 5.47159103 4.62333861 4.45561327 4.45288222 4.66633633
#  4.60958967 4.62022357 4.74050698 4.45448135 5.94232697 7.79008494]
# evaluated std of y : [0.31854553 0.36548063 0.05840252 0.72653212 0.30438189 0.24369472
#  0.0862756  0.38254565 0.23908561 0.10964916 0.20850551 0.21403299]
# ---------------------------------------
#
# The next datum recomended by Upper confidence bound  :
#  x =  [8.33333333]
# --------------Draw samples-------------
# real std of added datum: 0.5
# 1 -th sampling, result =  3.202973100514238
# 2 -th sampling, result =  3.85709488264519
# 3 -th sampling, result =  3.5997251114189477
# 4 -th sampling, result =  3.584520980422009
# 5 -th sampling, result =  2.4464178833484627
# evaluated mean of added datum: [3.33814639]
# evaluated std of added datum: 0.4923175706977928
# ---------------------------------------
#
# 1-th iteration
#  new added datum: [8.3, array([3.3381])]
# The next datum recomended by Upper confidence bound  :
#  x =  [8.]
# --------------Draw samples-------------
# real std of added datum: 0.2
# 1 -th sampling, result =  3.949182894378197
# 2 -th sampling, result =  3.4384160019064036
# 3 -th sampling, result =  3.4154948647362886
# 4 -th sampling, result =  3.4434093704860107
# 5 -th sampling, result =  3.4558580572577897
# evaluated mean of added datum: [3.54047224]
# evaluated std of added datum: 0.2047730351502849
# ---------------------------------------
#
# 2-th iteration
#  new added datum: [8.0, array([3.5405])]
# The next datum recomended by Upper confidence bound  :
#  x =  [8.22222222]
# --------------Draw samples-------------
# real std of added datum: 0.3
# 1 -th sampling, result =  3.093714094958935
# 2 -th sampling, result =  3.6115649100371496
# 3 -th sampling, result =  3.251800133339372
# 4 -th sampling, result =  3.166824021527154
# 5 -th sampling, result =  3.675065882806133
# evaluated mean of added datum: [3.35979381]
# evaluated std of added datum: 0.23769036788379197
# ---------------------------------------
#
# 3-th iteration
#  new added datum: [8.2, array([3.3598])]
# The next datum recomended by Upper confidence bound  :
#  x =  [8.22222222]
# --------------Draw samples-------------
# real std of added datum: 0.6
# 1 -th sampling, result =  3.9388739146096228
# 2 -th sampling, result =  2.9716817543892526
# 3 -th sampling, result =  4.078201428778457
# 4 -th sampling, result =  4.160602628691456
# 5 -th sampling, result =  2.623655124047713
# evaluated mean of added datum: [3.55460297]
# evaluated std of added datum: 0.6317461716121157
# ---------------------------------------
#
# 4-th iteration
#  new added datum: [8.2, array([3.5546])]
# The next datum recomended by Upper confidence bound  :
#  x =  [8.22222222]
# --------------Draw samples-------------
# real std of added datum: 0.5
# 1 -th sampling, result =  3.5924291649547904
# 2 -th sampling, result =  3.063520921007821
# 3 -th sampling, result =  3.1520107891445948
# 4 -th sampling, result =  2.461046929266507
# 5 -th sampling, result =  4.143952091982662
# evaluated mean of added datum: [3.28259198]
# evaluated std of added datum: 0.5617686659779738
# ---------------------------------------
#
# 5-th iteration
#  new added datum: [8.2, array([3.2826])]
# The next datum recomended by Upper confidence bound  :
#  x =  [7.88888889]
# --------------Draw samples-------------
# real std of added datum: 0.2
# 1 -th sampling, result =  3.3414514990539828
# 2 -th sampling, result =  3.5487376835983544
# 3 -th sampling, result =  3.5057678288464063
# 4 -th sampling, result =  3.3113167581613547
# 5 -th sampling, result =  3.752283959994542
# evaluated mean of added datum: [3.49191155]
# evaluated std of added datum: 0.1590394313241184
# ---------------------------------------
#
# 6-th iteration
#  new added datum: [7.9, array([3.4919])]
# The next datum recomended by Upper confidence bound  :
#  x =  [8.22222222]
# --------------Draw samples-------------
# real std of added datum: 0.1
# 1 -th sampling, result =  3.740568837567049
# 2 -th sampling, result =  3.564729473887834
# 3 -th sampling, result =  3.6865282463607136
# 4 -th sampling, result =  3.3908859326612553
# 5 -th sampling, result =  3.646108126997782
# evaluated mean of added datum: [3.60576412]
# evaluated std of added datum: 0.12180252252011335
# ---------------------------------------
#
# 7-th iteration
#  new added datum: [8.2, array([3.6058])]
# The next datum recomended by Upper confidence bound  :
#  x =  [8.22222222]
# --------------Draw samples-------------
# real std of added datum: 0.2
# 1 -th sampling, result =  3.6543904709331745
# 2 -th sampling, result =  3.548622484997748
# 3 -th sampling, result =  3.5298475819263775
# 4 -th sampling, result =  3.9554521112068137
# 5 -th sampling, result =  3.832523996126937
# evaluated mean of added datum: [3.70416733]
# evaluated std of added datum: 0.16533528605785433
# ---------------------------------------
#
# 8-th iteration
#  new added datum: [8.2, array([3.7042])]
# The next datum recomended by Upper confidence bound  :
#  x =  [7.11111111]
# --------------Draw samples-------------
# real std of added datum: 0.1
# 1 -th sampling, result =  3.714394669168551
# 2 -th sampling, result =  3.5234648355319775
# 3 -th sampling, result =  3.6419883965966973
# 4 -th sampling, result =  3.483393204967024
# 5 -th sampling, result =  3.6684174809020105
# evaluated mean of added datum: [3.60633172]
# evaluated std of added datum: 0.0880731971665134
# ---------------------------------------
#
# 9-th iteration
#  new added datum: [7.1, array([3.6063])]
# The next datum recomended by Upper confidence bound  :
#  x =  [6.33333333]
# --------------Draw samples-------------
# real std of added datum: 0.6
# 1 -th sampling, result =  2.949822227698591
# 2 -th sampling, result =  4.390219068989488
# 3 -th sampling, result =  4.545250582865444
# 4 -th sampling, result =  4.029709536649396
# 5 -th sampling, result =  3.587794641727554
# evaluated mean of added datum: [3.90055921]
# evaluated std of added datum: 0.5785837943303669
# ---------------------------------------
#
# 10-th iteration
#  new added datum: [6.3, array([3.9006])]
# The next datum recomended by Upper confidence bound  :
#  x =  [7.77777778]
# --------------Draw samples-------------
# real std of added datum: 0.6
# 1 -th sampling, result =  4.09995350430347
# 2 -th sampling, result =  3.725078422514188
# 3 -th sampling, result =  2.312667775429486
# 4 -th sampling, result =  2.8910722226482033
# 5 -th sampling, result =  3.856095716392931
# evaluated mean of added datum: [3.37697353]
# evaluated std of added datum: 0.6696688657281596
# ---------------------------------------
#
# 11-th iteration
#  new added datum: [7.8, array([3.377])]

# %%
obs = 5
guessed_noise_std = 0.5

data = pd.read_csv('data.csv')
data_matrix, Measured_response,Measured_std = generate_function(data,obs)
Y1=data.iloc[:,1:]

for i in range(500):
    plt.figure()
    ax1 = plt.subplot()
    ax1.set_ylim([3, 9])
    
   
    class Kriging_model(object):
        def fit_pre(self,xtrain,ytrain,xtest):
            # instantiated model
            kernel = RBF() 
            mdoel = GaussianProcessRegressor(kernel=kernel,normalize_y=True,alpha = guessed_noise_std**2).fit(xtrain,ytrain)
            # defined the attribute's outputs
            mean,std = mdoel.predict(xtest,return_std=True)
            return mean,std  
    

    y_mean_pre,y_mean_std = Kriging_model().fit_pre(data_matrix, Measured_response, virtual_samples.reshape(-1,1))
    ax1.scatter(data_matrix,Measured_response,c='r',s=50,zorder=10,edgecolors=(0,0,0),label="training data")
    ax1.plot(virtual_samples,True_function(virtual_samples),'b',lw=2,label="ture function")
    ax1.plot(virtual_samples,y_mean_pre,'k--',lw=2,zorder=9,label="predicted function")
    ax1.fill_between(virtual_samples,y_mean_pre-y_mean_std,y_mean_pre+y_mean_std,alpha=0.2,color='lightblue')
    ax1.plot(virtual_samples,y_mean_pre-y_mean_std,'g--',lw=1,label=' ± Sn(x)') 
    ax1.plot(virtual_samples,y_mean_pre+y_mean_std,'g--',lw=1)

    
    Bgolearn = BGOS.Bgolearn()
    # min_search = False:  searching the global maximum
    model = Bgolearn.fit(Kriging_model,data_matrix,Measured_response,virtual_samples,opt_num = 1,min_search = True)
    # recall the utility function 
    _return = model.UCB()
    
    
    index = np.random.choice(np.flatnonzero(_return == _return.min()))
    recommend = virtual_samples[index]
    ax1.plot(virtual_samples,_return,'y--',lw=2,label='{name}(x)'.format(name = method_name))
    
    # give an intrinsic std to recommended datum
    sam_std = round(random.uniform(0.1,0.7),1)
    datum_y, datum_std, Y_list = Sam_function(round(recommend,1),sam_std,obs)
    Measured_std = np.append(Measured_std,datum_std)
    data_matrix = np.append(data_matrix,np.round(recommend,1)).reshape(-1,1)
    Measured_response = np.append(Measured_response,np.round(datum_y,4))
    Y1 = np.append(Y1,Y_list)
 
    Measured_std1=(pd.DataFrame(Measured_std.reshape(len(Measured_std),1),columns=['Measured_std']))
    Measured_response1=(pd.DataFrame(Measured_response.reshape(len(Measured_std),1),columns=['Measured_response']))
    data_matrix1=(pd.DataFrame(data_matrix.reshape(len(data_matrix),1),columns=['x']))
    Y1=(pd.DataFrame(Y1.reshape(len(data_matrix),5)))
    data_iter=(np.hstack((data_matrix1,Measured_response1,Measured_std1,Y1)))
    
 
    
    print("{num}-th iteration".format(num = i + 1),'\n', 'new added datum:',([np.round(recommend,1),np.round(datum_y,4)]))
    ax1.scatter(round(recommend,1),_return[index],c='red',s=1.5,linewidths=8,label="recommended datum") 
    
    
    plt.text(0.1,3.2,'Method : {name}'.format(name = method_name),fontsize=12,color='k')
    plt.text(0.1,3.7,'Iter={}'.format(i),fontsize=12,color='k')
    plt.xlabel('x',fontsize = 12)
    plt.ylabel('y',fontsize = 12)
    plt.legend(fontsize = 11)
    plt.savefig('{name}-sd_{sdlevel}-obs_{obstime}-{num}.png'.format(name = method_name,sdlevel=guessed_noise_std,obstime = obs,num = i),dpi=800)
    plt.show()
    plt.clf()
    if 7.6 <= round(recommend,1) <= 7.8:
        break
    elif i>=10:
        print('Searching is defeated')
        break
data_iter=pd.DataFrame(data_iter.reshape(len(data_matrix),8),columns=['x','y_mean',"y_sd","y1","y2","y3","y4","y5"])
data_iter.to_csv('sd{:.2f}data.csv'.format(guessed_noise_std),float_format='%.4f') #保留两位小数
# Out:
# ------------12 original data-----------
# evaluated mean of y : [6.38302126 5.47159103 4.62333861 4.45561327 4.45288222 4.66633633
#  4.60958967 4.62022357 4.74050698 4.45448135 5.94232697 7.79008494]
# evaluated std of y : [0.31854553 0.36548063 0.05840252 0.72653212 0.30438189 0.24369472
#  0.0862756  0.38254565 0.23908561 0.10964916 0.20850551 0.21403299]
# ---------------------------------------
#
# The next datum recomended by Upper confidence bound  :
#  x =  [8.33333333]
# --------------Draw samples-------------
# real std of added datum: 0.1
# 1 -th sampling, result =  3.5559197927139827
# 2 -th sampling, result =  3.704572290545982
# 3 -th sampling, result =  3.7275570586224682
# 4 -th sampling, result =  3.606015041636827
# 5 -th sampling, result =  3.7072809196099117
# evaluated mean of added datum: [3.66026902]
# evaluated std of added datum: 0.06713096756502501
# ---------------------------------------
#
# 1-th iteration
#  new added datum: [8.3, array([3.6603])]
# The next datum recomended by Upper confidence bound  :
#  x =  [8.11111111]
# --------------Draw samples-------------
# real std of added datum: 0.6
# 1 -th sampling, result =  3.9484816050204303
# 2 -th sampling, result =  2.2568833051936
# 3 -th sampling, result =  3.442237429420253
# 4 -th sampling, result =  2.7915235243486114
# 5 -th sampling, result =  4.329118888874274
# evaluated mean of added datum: [3.35364895]
# evaluated std of added datum: 0.7526081691827933
# ---------------------------------------
#
# 2-th iteration
#  new added datum: [8.1, array([3.3536])]
# The next datum recomended by Upper confidence bound  :
#  x =  [7.77777778]
# --------------Draw samples-------------
# real std of added datum: 0.2
# 1 -th sampling, result =  3.6225687863304903
# 2 -th sampling, result =  3.8924997378638198
# 3 -th sampling, result =  3.4622034540926254
# 4 -th sampling, result =  3.1507069896791378
# 5 -th sampling, result =  3.570100092817335
# evaluated mean of added datum: [3.53961581]
# evaluated std of added datum: 0.24065755658032698
# ---------------------------------------
#
# 3-th iteration
#  new added datum: [7.8, array([3.5396])]

# %%
obs = 5
guessed_noise_std = 0.7

data = pd.read_csv('data.csv')
data_matrix, Measured_response,Measured_std = generate_function(data,obs)
Y1=data.iloc[:,1:]

for i in range(500):
    plt.figure()
    ax1 = plt.subplot()
    ax1.set_ylim([3, 9])
    
   
    class Kriging_model(object):
        def fit_pre(self,xtrain,ytrain,xtest):
            # instantiated model
            kernel = RBF() 
            mdoel = GaussianProcessRegressor(kernel=kernel,normalize_y=True,alpha = guessed_noise_std**2).fit(xtrain,ytrain)
            # defined the attribute's outputs
            mean,std = mdoel.predict(xtest,return_std=True)
            return mean,std  
    

    y_mean_pre,y_mean_std = Kriging_model().fit_pre(data_matrix, Measured_response, virtual_samples.reshape(-1,1))
    ax1.scatter(data_matrix,Measured_response,c='r',s=50,zorder=10,edgecolors=(0,0,0),label="training data")
    ax1.plot(virtual_samples,True_function(virtual_samples),'b',lw=2,label="ture function")
    ax1.plot(virtual_samples,y_mean_pre,'k--',lw=2,zorder=9,label="predicted function")
    ax1.fill_between(virtual_samples,y_mean_pre-y_mean_std,y_mean_pre+y_mean_std,alpha=0.2,color='lightblue')
    ax1.plot(virtual_samples,y_mean_pre-y_mean_std,'g--',lw=1,label=' ± Sn(x)') 
    ax1.plot(virtual_samples,y_mean_pre+y_mean_std,'g--',lw=1)

    
    Bgolearn = BGOS.Bgolearn()
    # min_search = False:  searching the global maximum
    model = Bgolearn.fit(Kriging_model,data_matrix,Measured_response,virtual_samples,opt_num = 1,min_search = True)
    # recall the utility function 
    _return = model.UCB()
    
    
    index = np.random.choice(np.flatnonzero(_return == _return.min()))
    recommend = virtual_samples[index]
    ax1.plot(virtual_samples,_return,'y--',lw=2,label='{name}(x)'.format(name = method_name))
    
    # give an intrinsic std to recommended datum
    sam_std = round(random.uniform(0.1,0.7),1)
    datum_y, datum_std, Y_list = Sam_function(round(recommend,1),sam_std,obs)
    Measured_std = np.append(Measured_std,datum_std)
    data_matrix = np.append(data_matrix,np.round(recommend,1)).reshape(-1,1)
    Measured_response = np.append(Measured_response,np.round(datum_y,4))
    Y1 = np.append(Y1,Y_list)
 
    Measured_std1=(pd.DataFrame(Measured_std.reshape(len(Measured_std),1),columns=['Measured_std']))
    Measured_response1=(pd.DataFrame(Measured_response.reshape(len(Measured_std),1),columns=['Measured_response']))
    data_matrix1=(pd.DataFrame(data_matrix.reshape(len(data_matrix),1),columns=['x']))
    Y1=(pd.DataFrame(Y1.reshape(len(data_matrix),5)))
    data_iter=(np.hstack((data_matrix1,Measured_response1,Measured_std1,Y1)))
    
 
    
    print("{num}-th iteration".format(num = i + 1),'\n', 'new added datum:',([np.round(recommend,1),np.round(datum_y,4)]))
    ax1.scatter(round(recommend,1),_return[index],c='red',s=1.5,linewidths=8,label="recommended datum") 
    
    
    plt.text(0.1,3.2,'Method : {name}'.format(name = method_name),fontsize=12,color='k')
    plt.text(0.1,3.7,'Iter={}'.format(i),fontsize=12,color='k')
    plt.xlabel('x',fontsize = 12)
    plt.ylabel('y',fontsize = 12)
    plt.legend(fontsize = 11)
    plt.savefig('{name}-sd_{sdlevel}-obs_{obstime}-{num}.png'.format(name = method_name,sdlevel=guessed_noise_std,obstime = obs,num = i),dpi=800)
    plt.show()
    plt.clf()
    if 7.6 <= round(recommend,1) <= 7.8:
        break
    elif i>=10:
        print('Searching is defeated')
        break
data_iter=pd.DataFrame(data_iter.reshape(len(data_matrix),8),columns=['x','y_mean',"y_sd","y1","y2","y3","y4","y5"])
data_iter.to_csv('sd{:.2f}data.csv'.format(guessed_noise_std),float_format='%.4f') #保留两位小数
# Out:
# ------------12 original data-----------
# evaluated mean of y : [6.38302126 5.47159103 4.62333861 4.45561327 4.45288222 4.66633633
#  4.60958967 4.62022357 4.74050698 4.45448135 5.94232697 7.79008494]
# evaluated std of y : [0.31854553 0.36548063 0.05840252 0.72653212 0.30438189 0.24369472
#  0.0862756  0.38254565 0.23908561 0.10964916 0.20850551 0.21403299]
# ---------------------------------------
#
# The next datum recomended by Upper confidence bound  :
#  x =  [8.33333333]
# --------------Draw samples-------------
# real std of added datum: 0.7
# 1 -th sampling, result =  2.3577817702901687
# 2 -th sampling, result =  3.8330411345126825
# 3 -th sampling, result =  4.58151775806034
# 4 -th sampling, result =  3.500540788525918
# 5 -th sampling, result =  3.424571126947815
# evaluated mean of added datum: [3.53949052]
# evaluated std of added datum: 0.7187700391310967
# ---------------------------------------
#
# 1-th iteration
#  new added datum: [8.3, array([3.5395])]
# The next datum recomended by Upper confidence bound  :
#  x =  [8.]
# --------------Draw samples-------------
# real std of added datum: 0.7
# 1 -th sampling, result =  3.3615658137067226
# 2 -th sampling, result =  3.879042532667577
# 3 -th sampling, result =  4.500876367797072
# 4 -th sampling, result =  3.9271169081570516
# 5 -th sampling, result =  2.984175602613811
# evaluated mean of added datum: [3.73055544]
# evaluated std of added datum: 0.5190983269523709
# ---------------------------------------
#
# 2-th iteration
#  new added datum: [8.0, array([3.7306])]
# The next datum recomended by Upper confidence bound  :
#  x =  [7.88888889]
# --------------Draw samples-------------
# real std of added datum: 0.6
# 1 -th sampling, result =  2.2612803879678847
# 2 -th sampling, result =  4.68042932055505
# 3 -th sampling, result =  3.1240262975343973
# 4 -th sampling, result =  4.064033065055846
# 5 -th sampling, result =  4.070830483815654
# evaluated mean of added datum: [3.64011991]
# evaluated std of added datum: 0.8502950870681255
# ---------------------------------------
#
# 3-th iteration
#  new added datum: [7.9, array([3.6401])]
# The next datum recomended by Upper confidence bound  :
#  x =  [7.77777778]
# --------------Draw samples-------------
# real std of added datum: 0.3
# 1 -th sampling, result =  4.02456663339346
# 2 -th sampling, result =  3.2200274831811617
# 3 -th sampling, result =  3.675427937657611
# 4 -th sampling, result =  3.2335185484357427
# 5 -th sampling, result =  3.1697637002030796
# evaluated mean of added datum: [3.46466086]
# evaluated std of added datum: 0.3341119058665838
# ---------------------------------------
#
# 4-th iteration
#  new added datum: [7.8, array([3.4647])]
