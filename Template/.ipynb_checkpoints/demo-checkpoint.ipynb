# %% [markdown]
# # Example, Cao Bin, Jul 8 2022

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF,WhiteKernel

# %%
import Bgolearn.BGOsampling as BGOS
# Out:
#  Bgolearn : A Bayesian global optimization package
#  10 Jul 2022, version 1, Bin Cao, MGI, SHU, Shanghai, CHINA.

# %% [markdown]
# # It's a noise-free example

# %% [markdown]
# ## 1 : input the dataset

# %%
data = pd.read_csv('data.csv')
data_matrix = data.iloc[:,:-1]
Measured_response = data.iloc[:,-1]

# %% [markdown]
# ## 2 : design virtual samples

# %%
# searching domain is [0,11]
virtual_samples = np.linspace(0,11,100)

# %%
# true function 
def function(X):
    X = np.array(X)
    Y = 0.013*X**4 - 0.25*X**3 + 1.61*X**2 - 4.1*X + 8
    return Y

plt.figure()
ax1 = plt.subplot()
ax1.scatter(data_matrix,Measured_response,c='r',s=50,zorder=10,edgecolors=(0,0,0),label="training data")
ax1.plot(virtual_samples,function(virtual_samples),'b',lw=2,label="ture function")
plt.xlabel('x',fontsize = 12)
plt.ylabel('y',fontsize = 12)
plt.legend(fontsize = 11)

# %% [markdown]
# ## 3 : define a callable Kriging model

# %%
"""
Kriging_model: 
a defined callable Kriging model, has an attribute of <fit_pre>
atribute <fit_pre> : 
input -> xtrain, ytrain, xtest;
output -> predicted mean and std of xtest
e.g.
"""
class Kriging_model(object):
    def fit_pre(self,xtrain,ytrain,xtest):
        # instantiated model
        kernel = RBF() + WhiteKernel()
        mdoel = GaussianProcessRegressor(kernel=kernel,normalize_y=True,).fit(xtrain,ytrain)
        # defined the attribute's outputs
        mean,std = mdoel.predict(xtest,return_std=True)
        return mean,std

# %% [markdown]
# ## 4 : gives the next recommendation by Bayesian Global Optimization

# %% [markdown]
# + Expected Improvement

# %%
plt.figure()
ax1 = plt.subplot()

y_mean_pre,y_mean_std = Kriging_model().fit_pre(data_matrix,Measured_response,virtual_samples.reshape(-1,1))
ax1.scatter(data_matrix,Measured_response,c='r',s=50,zorder=10,edgecolors=(0,0,0),label="training data")
ax1.plot(virtual_samples,function(virtual_samples),'b',lw=2,label="ture function")
ax1.plot(virtual_samples,y_mean_pre,'k--',lw=2,zorder=9,label="predicted function")
ax1.fill_between(virtual_samples,y_mean_pre-y_mean_std,y_mean_pre+y_mean_std,alpha=0.2,color='lightblue')
ax1.plot(virtual_samples,y_mean_pre-y_mean_std,'g--',lw=1,label=' ± sigma') 
ax1.plot(virtual_samples,y_mean_pre+y_mean_std,'g--',lw=1)

Bgolearn = BGOS.Bgolearn()
# min_search = False:  searching the global maximum
model = Bgolearn.fit(Kriging_model,data_matrix,Measured_response,virtual_samples,opt_num = 3,min_search = True)
ax1.plot(virtual_samples,model.EI()*10 + 3,'r--',lw=2,label='Expected Improvement value')


plt.xlabel('x',fontsize = 12)
plt.ylabel('y',fontsize = 12)
plt.legend(fontsize = 11)
# Out:
# current optimal is : 4.4140625
# The 1-th datum recomended by Expected Improvement :
#  x =  [6.55555556]
# The 2-th datum recomended by Expected Improvement :
#  x =  [6.33333333]
# The 3-th datum recomended by Expected Improvement :
#  x =  [6.44444444]
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but GaussianProcessRegressor was fitted with feature names
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(

# %% [markdown]
# + Expected improvement with “plugin”

# %%
plt.figure()
ax1 = plt.subplot()

y_mean_pre,y_mean_std = Kriging_model().fit_pre(data_matrix,Measured_response,virtual_samples.reshape(-1,1))
ax1.scatter(data_matrix,Measured_response,c='r',s=50,zorder=10,edgecolors=(0,0,0),label="training data")
ax1.plot(virtual_samples,function(virtual_samples),'b',lw=2,label="ture function")
ax1.plot(virtual_samples,y_mean_pre,'k--',lw=2,zorder=9,label="predicted function")
ax1.fill_between(virtual_samples,y_mean_pre-y_mean_std,y_mean_pre+y_mean_std,alpha=0.2,color='lightblue')
ax1.plot(virtual_samples,y_mean_pre-y_mean_std,'g--',lw=1,label=' ± sigma') 
ax1.plot(virtual_samples,y_mean_pre+y_mean_std,'g--',lw=1)

Bgolearn = BGOS.Bgolearn()
model = Bgolearn.fit(Kriging_model,data_matrix,Measured_response,virtual_samples,opt_num = 3)
ax1.plot(virtual_samples,model.EI_plugin()*10 + 3,'r--',lw=2,label='EI_plugin')


plt.xlabel('x',fontsize = 12)
plt.ylabel('y',fontsize = 12)
plt.legend(fontsize = 11)
# Out:
# current optimal is : 4.413848889776276
# The 1-th datum recomended by Expected Improvement with plugin :
#  x =  [6.55555556]
# The 2-th datum recomended by Expected Improvement with plugin :
#  x =  [6.33333333]
# The 3-th datum recomended by Expected Improvement with plugin :
#  x =  [6.44444444]
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but GaussianProcessRegressor was fitted with feature names
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(

# %% [markdown]
# + Augmented Expected Improvement

# %%
plt.figure()
ax1 = plt.subplot()

y_mean_pre,y_mean_std = Kriging_model().fit_pre(data_matrix,Measured_response,virtual_samples.reshape(-1,1))
ax1.scatter(data_matrix,Measured_response,c='r',s=50,zorder=10,edgecolors=(0,0,0),label="training data")
ax1.plot(virtual_samples,function(virtual_samples),'b',lw=2,label="ture function")
ax1.plot(virtual_samples,y_mean_pre,'k--',lw=2,zorder=9,label="predicted function")
ax1.fill_between(virtual_samples,y_mean_pre-y_mean_std,y_mean_pre+y_mean_std,alpha=0.2,color='lightblue')
ax1.plot(virtual_samples,y_mean_pre-y_mean_std,'g--',lw=1,label=' ± sigma') 
ax1.plot(virtual_samples,y_mean_pre+y_mean_std,'g--',lw=1)

Bgolearn = BGOS.Bgolearn()
model = Bgolearn.fit(Kriging_model,data_matrix,Measured_response,virtual_samples,opt_num = 3)
ax1.plot(virtual_samples,model.Augmented_EI(alpha = 1, tao = 0)*10 + 3,'r--',lw=2,label='EI_plugin')


plt.xlabel('x',fontsize = 12)
plt.ylabel('y',fontsize = 12)
plt.legend(fontsize = 11)
# Out:
# current optimal is : 4.413848889776276
# The 1-th datum recomended by Augmented_EI :
#  x =  [6.55555556]
# The 2-th datum recomended by Augmented_EI :
#  x =  [6.33333333]
# The 3-th datum recomended by Augmented_EI :
#  x =  [6.44444444]

# %% [markdown]
# + Expected Quantile Improvement

# %%
plt.figure()
ax1 = plt.subplot()

y_mean_pre,y_mean_std = Kriging_model().fit_pre(data_matrix,Measured_response,virtual_samples.reshape(-1,1))
ax1.scatter(data_matrix,Measured_response,c='r',s=50,zorder=10,edgecolors=(0,0,0),label="training data")
ax1.plot(virtual_samples,function(virtual_samples),'b',lw=2,label="ture function")
ax1.plot(virtual_samples,y_mean_pre,'k--',lw=2,zorder=9,label="predicted function")
ax1.fill_between(virtual_samples,y_mean_pre-y_mean_std,y_mean_pre+y_mean_std,alpha=0.2,color='lightblue')
ax1.plot(virtual_samples,y_mean_pre-y_mean_std,'g--',lw=1,label=' ± sigma') 
ax1.plot(virtual_samples,y_mean_pre+y_mean_std,'g--',lw=1)

Bgolearn = BGOS.Bgolearn()
model = Bgolearn.fit(Kriging_model,data_matrix,Measured_response,virtual_samples,opt_num = 3)
ax1.plot(virtual_samples,model.EQI(beta = 0.5,tao_new = 0)*10 + 3,'r--',lw=2,label='EI_plugin')


plt.xlabel('x',fontsize = 12)
plt.ylabel('y',fontsize = 12)
plt.legend(fontsize = 11)
# Out:
# current optimal is : 4.413848889776276
# The 1-th datum recomended by Expected Quantile Improvement :
#  x =  [6.55555556]
# The 2-th datum recomended by Expected Quantile Improvement :
#  x =  [6.33333333]
# The 3-th datum recomended by Expected Quantile Improvement :
#  x =  [6.44444444]

# %% [markdown]
# + Reinterpolation Expected Improvement

# %%
plt.figure()
ax1 = plt.subplot()

y_mean_pre,y_mean_std = Kriging_model().fit_pre(data_matrix,Measured_response,virtual_samples.reshape(-1,1))
ax1.scatter(data_matrix,Measured_response,c='r',s=50,zorder=10,edgecolors=(0,0,0),label="training data")
ax1.plot(virtual_samples,function(virtual_samples),'b',lw=2,label="ture function")
ax1.plot(virtual_samples,y_mean_pre,'k--',lw=2,zorder=9,label="predicted function")
ax1.fill_between(virtual_samples,y_mean_pre-y_mean_std,y_mean_pre+y_mean_std,alpha=0.2,color='lightblue')
ax1.plot(virtual_samples,y_mean_pre-y_mean_std,'g--',lw=1,label=' ± sigma') 
ax1.plot(virtual_samples,y_mean_pre+y_mean_std,'g--',lw=1)

Bgolearn = BGOS.Bgolearn()
model = Bgolearn.fit(Kriging_model,data_matrix,Measured_response,virtual_samples,opt_num = 3)
ax1.plot(virtual_samples,model.Reinterpolation_EI()*10 + 3,'r--',lw=2,label='EI_plugin')


plt.xlabel('x',fontsize = 12)
plt.ylabel('y',fontsize = 12)
plt.legend(fontsize = 11)
# Out:
# current optimal is : 4.413848889776276
# The 1-th datum recomended by Reinterpolation Expected Improvement :
#  x =  [6.55555556]
# The 2-th datum recomended by Reinterpolation Expected Improvement :
#  x =  [6.33333333]
# The 3-th datum recomended by Reinterpolation Expected Improvement :
#  x =  [6.44444444]

# %% [markdown]
# + Upper confidence bound

# %%
plt.figure()
ax1 = plt.subplot()

y_mean_pre,y_mean_std = Kriging_model().fit_pre(data_matrix,Measured_response,virtual_samples.reshape(-1,1))
ax1.scatter(data_matrix,Measured_response,c='r',s=50,zorder=10,edgecolors=(0,0,0),label="training data")
ax1.plot(virtual_samples,function(virtual_samples),'b',lw=2,label="ture function")
ax1.plot(virtual_samples,y_mean_pre,'k--',lw=2,zorder=9,label="predicted function")
ax1.fill_between(virtual_samples,y_mean_pre-y_mean_std,y_mean_pre+y_mean_std,alpha=0.2,color='lightblue')
ax1.plot(virtual_samples,y_mean_pre-y_mean_std,'g--',lw=1,label=' ± sigma') 
ax1.plot(virtual_samples,y_mean_pre+y_mean_std,'g--',lw=1)

Bgolearn = BGOS.Bgolearn()
model = Bgolearn.fit(Kriging_model,data_matrix,Measured_response,virtual_samples,opt_num = 3)
ax1.plot(virtual_samples,model.UCB(alpha=1) ,'r--',lw=2,label='EI_plugin')


plt.xlabel('x',fontsize = 12)
plt.ylabel('y',fontsize = 12)
plt.legend(fontsize = 11)
# Out:
# The 1-th datum recomended by Upper confidence bound :
#  x =  [6.44444444]
# The 2-th datum recomended by Upper confidence bound :
#  x =  [6.22222222]
# The 3-th datum recomended by Upper confidence bound :
#  x =  [6.33333333]

# %% [markdown]
# + Probability of Improvement

# %%
plt.figure()
ax1 = plt.subplot()

y_mean_pre,y_mean_std = Kriging_model().fit_pre(data_matrix,Measured_response,virtual_samples.reshape(-1,1))
ax1.scatter(data_matrix,Measured_response,c='r',s=50,zorder=10,edgecolors=(0,0,0),label="training data")
ax1.plot(virtual_samples,function(virtual_samples),'b',lw=2,label="ture function")
ax1.plot(virtual_samples,y_mean_pre,'k--',lw=2,zorder=9,label="predicted function")
ax1.fill_between(virtual_samples,y_mean_pre-y_mean_std,y_mean_pre+y_mean_std,alpha=0.2,color='lightblue')
ax1.plot(virtual_samples,y_mean_pre-y_mean_std,'g--',lw=1,label=' ± sigma') 
ax1.plot(virtual_samples,y_mean_pre+y_mean_std,'g--',lw=1)

Bgolearn = BGOS.Bgolearn()
model = Bgolearn.fit(Kriging_model,data_matrix,Measured_response,virtual_samples,opt_num = 3)
ax1.plot(virtual_samples,model.PoI(tao = 0)*10 + 3 ,'r--',lw=2,label='EI_plugin')


plt.xlabel('x',fontsize = 12)
plt.ylabel('y',fontsize = 12)
plt.legend(fontsize = 11)
# Out:
# please input a postive value of tao
# current optimal is : 4.4140625
# The 1-th datum recomended by Probability of Improvement  :
#  x =  [2.22222222]
# The 2-th datum recomended by Probability of Improvement  :
#  x =  [2.44444444]
# The 3-th datum recomended by Probability of Improvement  :
#  x =  [2.33333333]

# %% [markdown]
# + Predictive Entropy Search

# %%
plt.figure()
ax1 = plt.subplot()

y_mean_pre,y_mean_std = Kriging_model().fit_pre(data_matrix,Measured_response,virtual_samples.reshape(-1,1))
ax1.scatter(data_matrix,Measured_response,c='r',s=50,zorder=10,edgecolors=(0,0,0),label="training data")
ax1.plot(virtual_samples,function(virtual_samples),'b',lw=2,label="ture function")
ax1.plot(virtual_samples,y_mean_pre,'k--',lw=2,zorder=9,label="predicted function")
ax1.fill_between(virtual_samples,y_mean_pre-y_mean_std,y_mean_pre+y_mean_std,alpha=0.2,color='lightblue')
ax1.plot(virtual_samples,y_mean_pre-y_mean_std,'g--',lw=1,label=' ± sigma') 
ax1.plot(virtual_samples,y_mean_pre+y_mean_std,'g--',lw=1)

Bgolearn = BGOS.Bgolearn()
model = Bgolearn.fit(Kriging_model,data_matrix,Measured_response,virtual_samples,opt_num = 3)
ax1.plot(virtual_samples,model.PES(sam_num = 500) + 3 ,'r--',lw=2,label='EI_plugin')


plt.xlabel('x',fontsize = 12)
plt.ylabel('y',fontsize = 12)
plt.legend(fontsize = 11)
# Out:
# The 1-th datum recomended by Predictive Entropy Search  :
#  x =  [6.66666667]
# The 2-th datum recomended by Predictive Entropy Search  :
#  x =  [6.33333333]
# The 3-th datum recomended by Predictive Entropy Search  :
#  x =  [6.44444444]

# %% [markdown]
# + Knowledge Gradient

# %%
plt.figure()
ax1 = plt.subplot()

y_mean_pre,y_mean_std = Kriging_model().fit_pre(data_matrix,Measured_response,virtual_samples.reshape(-1,1))
ax1.scatter(data_matrix,Measured_response,c='r',s=50,zorder=10,edgecolors=(0,0,0),label="training data")
ax1.plot(virtual_samples,function(virtual_samples),'b',lw=2,label="ture function")
ax1.plot(virtual_samples,y_mean_pre,'k--',lw=2,zorder=9,label="predicted function")
ax1.fill_between(virtual_samples,y_mean_pre-y_mean_std,y_mean_pre+y_mean_std,alpha=0.2,color='lightblue')
ax1.plot(virtual_samples,y_mean_pre-y_mean_std,'g--',lw=1,label=' ± sigma') 
ax1.plot(virtual_samples,y_mean_pre+y_mean_std,'g--',lw=1)

Bgolearn = BGOS.Bgolearn()
model = Bgolearn.fit(Kriging_model,data_matrix,Measured_response,virtual_samples,opt_num = 3)
ax1.plot(virtual_samples,model.KD(MC_num = 500)*10 + 3 ,'r--',lw=2,label='EI_plugin')


plt.xlabel('x',fontsize = 12)
plt.ylabel('y',fontsize = 12)
plt.legend(fontsize = 11)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but GaussianProcessRegressor was fitted with feature names
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# The 2000-th Monte carlo simulation
# The 4000-th Monte carlo simulation
# The 6000-th Monte carlo simulation
# The 8000-th Monte carlo simulation
# The 10000-th Monte carlo simulation
# The 12000-th Monte carlo simulation
# The 14000-th Monte carlo simulation
# The 16000-th Monte carlo simulation
# The 18000-th Monte carlo simulation
# The 20000-th Monte carlo simulation
# The 22000-th Monte carlo simulation
# The 24000-th Monte carlo simulation
# The 26000-th Monte carlo simulation
# The 28000-th Monte carlo simulation
# The 30000-th Monte carlo simulation
# The 32000-th Monte carlo simulation
# The 34000-th Monte carlo simulation
# The 36000-th Monte carlo simulation
# The 38000-th Monte carlo simulation
# The 40000-th Monte carlo simulation
# The 42000-th Monte carlo simulation
# The 44000-th Monte carlo simulation
# The 46000-th Monte carlo simulation
# The 48000-th Monte carlo simulation
# The 50000-th Monte carlo simulation
# The 1-th datum recomended by Knowledge Gradient :
#  x =  [6.55555556]
# The 2-th datum recomended by Knowledge Gradient :
#  x =  [6.66666667]
# The 3-th datum recomended by Knowledge Gradient :
#  x =  [6.33333333]
